# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import io
from PIL import Image
from IPython.display import Image as IPyImage, display
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import sys
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/PIV/')   
sys.path.append('/Users/kjesta/Desktop/LABDATA/PIV/')

import imageio
import pathlib
import cmcrameri.cm as cm
import pandas as pd

import matplotlib.style as mplstyle
mplstyle.use(["ggplot", "fast"])

# %%
figpath = pathlib.Path('/Users/kjesta/Desktop/LABDATA/PIV/results/zoom/figs/f14a03/')
output_path = pathlib.Path('/Users/kjesta/Desktop/LABDATA/PIV/results/zoom/gifs/')

# Make gif of velocity fields

stepsize = 4

gif_frames_r1 = []

for i in range(1250, 1516-stepsize, stepsize):
    img_path = figpath / f'vel_field_{i}_r1.png'
    gif_frames_r1.append(imageio.imread(img_path))

imageio.mimwrite(output_path / 'f14a03_velocity_field_r1.gif', gif_frames_r1, fps=10)

# Make gif of velocity fields

gif_frames_r2 = []

for i in range(1250, 1516-stepsize, stepsize):
    img_path = figpath / f'vel_field_{i}_r2.png'
    gif_frames_r2.append(imageio.imread(img_path))

imageio.mimwrite(output_path / 'f14a03_velocity_field_r2.gif', gif_frames_r2, fps=10)

# Make gif of velocity fields

gif_frames_r3 = []

for i in range(1250, 1516-stepsize, stepsize):
    img_path = figpath / f'vel_field_{i}_r3.png'
    gif_frames_r3.append(imageio.imread(img_path))

imageio.mimwrite(output_path / 'f14a03_velocity_field_r3.gif', gif_frames_r3, fps=10)
# Out:
# /var/folders/tp/bn0hk5sx7fq7r171hlv9tzq40000gn/T/ipykernel_82086/249719634.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gif_frames_r1.append(imageio.imread(img_path))
# /var/folders/tp/bn0hk5sx7fq7r171hlv9tzq40000gn/T/ipykernel_82086/249719634.py:22: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gif_frames_r2.append(imageio.imread(img_path))
# ...

# %%
figpath = pathlib.Path('/Users/kjesta/Desktop/LABDATA/PIV/results/zoom/figs/f14a01/')
output_path = pathlib.Path('/Users/kjesta/Desktop/LABDATA/PIV/results/zoom/gifs/')

# Make gif of vorticity fields

stepsize = 6

gif_frames_r1 = []

for i in range(1250, 1516-stepsize, stepsize):
    img_path = figpath / f'curl_grad_{i}_r1.png'
    gif_frames_r1.append(imageio.imread(img_path))

imageio.mimwrite(output_path / 'f14a01_vorticity_field_r1.gif', gif_frames_r1, fps=10)

# Make gif of vorticity fields

gif_frames_r2 = []

for i in range(1250, 1516-stepsize, stepsize):
    img_path = figpath / f'curl_grad_{i}_r2.png'
    gif_frames_r2.append(imageio.imread(img_path))

imageio.mimwrite(output_path / 'f14a01_vorticity_field_r2.gif', gif_frames_r2, fps=10)

# Make gif of vorticity fields

gif_frames_r3 = []

for i in range(1250, 1516-stepsize, stepsize):
    img_path = figpath / f'curl_grad_{i}_r3.png'
    gif_frames_r3.append(imageio.imread(img_path))

imageio.mimwrite(output_path / 'f14a01_vorticity_field_r3.gif', gif_frames_r3, fps=10)
# Out:
# /var/folders/tp/bn0hk5sx7fq7r171hlv9tzq40000gn/T/ipykernel_82086/897405111.py:12: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gif_frames_r1.append(imageio.imread(img_path))
# /var/folders/tp/bn0hk5sx7fq7r171hlv9tzq40000gn/T/ipykernel_82086/897405111.py:22: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gif_frames_r2.append(imageio.imread(img_path))
# ...
