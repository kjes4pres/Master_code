# %%
from openpiv import tools, pyprocess, validation, filters, scaling

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import io
from PIL import Image
from IPython.display import Image as IPyImage, display
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import sys
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/PIV/')   

import imageio
import pathlib
import cmcrameri.cm as cm
import pandas as pd
from piv_func import perform_piv

import matplotlib.style as mplstyle
mplstyle.use(["ggplot", "fast"])

# %% [markdown]
# # Particle Image Velocimetry
# #### Kjersti Stangeland, Spring 2026
# **Analyzing**:
# * f = 1.4 Hz
# * A = 0.1 V
# * D = 0.2 m
# * H = 0.15 m
#
# Run 3 out of 3

# %%
# Opening frames needed for analyzing two wave periods
ims = np.linspace(1250, 1516, 267)  # Adjusted to cover three periods (1250 to 1516)
frames = {}

for im in ims:
    im_int = int(im)
    img = tools.imread(f'/Users/kjesta/Desktop/LABDATA/PIV/f14a01/bitmap3/image_p{im_int}.bmp')
    frames[im_int] = img

# %%
T = 1/1.4  # wave period, seconds
fps = 125  # frames per second
dt = 1/fps  # time between frames, seconds
fpp = fps*T  # frames per period
images_needed = int(3*fpp)

print(f"Frames per period: {fpp:.2f}")
print(f"Time between frames: {dt:.4f} s")
print(f"Total images needed for three periods: {images_needed}")
print(f"Frames opened: {len(frames)}")
# Out:
# Frames per period: 89.29
# Time between frames: 0.0080 s
# Total images needed for three periods: 267
# Frames opened: 267

# %%
timestamps = [i * dt + 10 for i in list(frames.keys())] # timestamps for one period, starting at 10 seconds

# %%
'''
Cutting out mid part of image. 
Want to avoid the free surface as the edge effects there
distort the velocity field.
I also match the indices to the reference photo to be sure the scaling is correct.
'''
y_min = 675
y_max = 1725

x_min = 15
x_max = 1250

# %%
fig, ax =plt.subplots(1,2, figsize=(12,10))
ax[0].imshow(frames[1250], cmap='gray')
ax[0].hlines(y=y_min, xmin=0, xmax=frames[1250].shape[1], colors='r', linestyles='--', label=f'y = {y_min} px')
ax[0].hlines(y=y_max, xmin=0, xmax=frames[1250].shape[1], colors='b', linestyles='--', label=f'y = {y_max} px')
ax[0].vlines(x=x_min, ymin=0, ymax=frames[1250].shape[0], colors='g', linestyles='--', label=f'x = {x_min} px')
ax[0].vlines(x=x_max, ymin=0, ymax=frames[1250].shape[0], colors='m', linestyles='--', label=f'x = {x_max} px')
ax[0].set_title(f't={timestamps[0]:.3f} s')

ax[1].imshow(frames[1251], cmap='gray')
ax[1].set_title(f't={timestamps[1]:.3f} s')
ax[1].hlines(y=y_min, xmin=0, xmax=frames[1251].shape[1], colors='r', linestyles='--')
ax[1].hlines(y=y_max, xmin=0, xmax=frames[1251].shape[1], colors='b', linestyles='--')
ax[1].vlines(x=x_min, ymin=0, ymax=frames[1251].shape[0], colors='g', linestyles='--')
ax[1].vlines(x=x_max, ymin=0, ymax=frames[1251].shape[0], colors='m', linestyles='--')

ax[0].grid()
ax[1].grid()
fig.legend(title='Region of analysis', loc='upper center', bbox_to_anchor=(0.5, 0.92), ncol=2)

# %%
# Zoom in on area of interest
# Ignoring the surface and the bottom of the frame
zoom_frames = {}
for key in frames.keys():
    zoom_frames[key] = frames[key][y_min:y_max, x_min:x_max]

# %%
plate_top_index = 748

# %%
fig, ax =plt.subplots(1,2, figsize=(12,6))
ax[0].imshow(zoom_frames[1250], cmap='gray')
ax[0].set_title(f't={timestamps[0]:.3f} s (zoomed)')
ax[0].hlines(y=plate_top_index, xmin=0, xmax=zoom_frames[1250].shape[1], colors='r', linestyles='--', label=f'Top of plates (y = {plate_top_index} px)')

ax[1].imshow(zoom_frames[1251], cmap='gray')
ax[1].set_title(f't={timestamps[1]:.3f} s (zoomed)')
ax[1].hlines(y=plate_top_index, xmin=0, xmax=zoom_frames[1251].shape[1], colors='r', linestyles='--')
ax[0].grid()
ax[1].grid()

fig.legend(loc='upper right', bbox_to_anchor=(0.85, 0.95), ncol=2)
fig.suptitle('Raw, zoomed in, frames', y=0.9)
# Out:
# Text(0.5, 0.9, 'Raw, zoomed in, frames')

# %%
# Load reference image
reference = tools.imread('/Users/kjesta/Desktop/LABDATA/PIV/reference_p29.bmp')

# %%
fig, ax =plt.subplots(1, figsize=(12, 12))
ax.imshow(reference, cmap='gray')
ax.vlines(x=x_max, ymin=0, ymax=reference.shape[0], colors='g', linestyles='--', label=f'x = {x_max} px')
ax.vlines(x=x_min, ymin=0, ymax=reference.shape[0], colors='m', linestyles='--', label=f'x = {x_min} px')
ax.hlines(y=y_min, xmin=0, xmax=reference.shape[1], colors='r', linestyles='--', label=f'y = {y_min} px')
ax.hlines(y=y_max, xmin=0, xmax=reference.shape[1], colors='b', linestyles='--', label=f'y = {y_max} px')
ax.legend(title='Region of analysis', loc='upper right', bbox_to_anchor=(0.85, 0.95), ncol=2)
ax.set_title('Reference')
ax.grid()

# %%
# Zoom in on reference image
reference_zoom = reference[y_min:y_max, x_min:x_max]

fig, ax =plt.subplots(1, figsize=(12,6))
ax.imshow(reference_zoom, cmap='gray')
ax.set_title('Reference image (zoomed)')
ax.hlines(y=plate_top_index, xmin=0, xmax=reference_zoom.shape[1], colors='r', linestyles='--')
ax.grid()

# %%
# Distance between pixel 15 and 1250 (in horizontal direction)
x_m = 0.21
# Distance between pixel 675 and 1725 (in vertical direction)
y_m = 0.18

# Calculate pixel to m scaling factors
x_scale = (x_max - x_min) / x_m  # pixel per m
y_scale = (y_max - y_min) / y_m  # pixel per m

print(f"x_scale = {x_scale:.3f} px/m, y_scale = {y_scale:.3f} px/m")
print(f'Percentage difference: {(x_scale-y_scale)/y_scale * 100:.2f}%')

# Average if appropriate
scaling_factor = (x_scale + y_scale) / 2
print(f"Average scaling factor: {scaling_factor:.3f} px/m")
# Out:
# x_scale = 5880.952 px/m, y_scale = 5833.333 px/m
# Percentage difference: 0.82%
# Average scaling factor: 5857.143 px/m

# %%
# Crop frames to region of interest
ims = np.linspace(1250, 1516, 267)
cropped_frames = {}

for im in ims:
    cropped_frames[int(im)] = frames[int(im)][y_min:y_max, x_min:x_max]

# %%
# Removing static background
static = np.median(list(cropped_frames.values()), axis=0)
cleaned_frames = {}
for key in cropped_frames.keys():
    cleaned_frames[key] = cropped_frames[key] - static

# %%
def depth_formatter(y_tick, pos):
        # depth: negative downward
        # Adding 0.02 m to shift the depth values so that it matches real water depth
        return f"{-(y_tick + 0.02):.2f}"

def x_phys_formatter(x_tick, pos):
        # Map image x → physical x (paddle at 8.06 m on the right)
        return f"{8.06 + (x_max - x_tick):.2f}"

# %%
# PIV parameters

window_size = 16  # interrogation window size (in pixels)
overlap = 8  # overlap between interrogation windows (in pixels)
search_area_size = 32  # search area size (in pixels)
stepsize = 1  # how many frames to skip between PIV analyses
threshold = 1.2  # sig2noise threshold for validation
max_iter = 10  
kernel_size = 2

# %%
len(cleaned_frames)-1
# Out:
# 266

# %%
# Lists for storing vertical velocity
# and vertical velocity gradient around the plates for each time step
w_bar = []
dw_bar = []

results = []

for key in range(1250, 1250+len(cleaned_frames)-1, stepsize):
    # Run PIV
    frame_a = cropped_frames[key]
    frame_b = cropped_frames[key + stepsize]
    
    idx_a = key - 1250
    idx_b = idx_a + stepsize

    time_a = timestamps[idx_a]
    time_b = timestamps[idx_b]

    dt = time_b - time_a

    # Perform PIV analysis
    u, v, sig2noise = pyprocess.extended_search_area_piv(
    frame_a, frame_b,
    window_size=window_size,
    overlap=overlap,
    dt=dt*stepsize,
    search_area_size=search_area_size)

    # Get coordinates
    x, y = pyprocess.get_coordinates(
    image_size=frame_a.shape,
    search_area_size=search_area_size,
    overlap=overlap)

    # 1) Signal-to-noise validation
    u, v, mask = validation.sig2noise_val(u, v, sig2noise, threshold=threshold)
    
    # 2) Local median validation
    u, v, mask = validation.local_median_val(
    u, v, u_threshold=50, v_threshold=50)

    flag_frac = np.mean(mask)
    print("Total flagged fraction after all validations: ", flag_frac)

    # 3) Replace outliers by local mean
    u, v = filters.replace_outliers(
    u, v,
    method='localmean',
    max_iter=max_iter,
    kernel_size=kernel_size)

    # 4) Scale to physical units
    x, y, u, v = scaling.uniform(x, y, u, v, scaling_factor=scaling_factor) 

    n_vec = u.size

    # Time indices for the two frames used in PIV
    idx_a = key - 1250
    time_a = timestamps[idx_a]
    idx_b = idx_a + stepsize
    time_b = timestamps[idx_b]

    # Calculate vorticity and velocity gradients
    curl_u = np.gradient(u, axis=0) # du/dz
    curl_w = np.gradient(v, axis=1) # dw/dx
    curl = curl_u - curl_w  # vorticity
    grad_u = np.gradient(u, axis=1) # du/dx
    grad_w = np.gradient(v, axis=0) # dw/dz

    # Find location of top of plates in physical units (m) and corresponding index in y array
    plate_top_m = plate_top_index/scaling_factor
    y_idx_plate_top = (np.abs(y[:, 0] - plate_top_m)).argmin()

    # Find average vertical velocity in the region of the plates
    no_w_vec = np.shape(v[y_idx_plate_top, :])
    w_mean = np.mean(v[y_idx_plate_top, :])
    w_bar.append(w_mean)
    dw_bar.append(np.mean(grad_w[y_idx_plate_top, :]))

    results.append({
        'time_a': time_a,
        'time_b': time_b,
        'w_bar': w_bar[-1],
        'dw_bar': dw_bar[-1],
        '# of vectors': n_vec,
        'flag_fraction': flag_frac,
        '# w vectors in mean': no_w_vec
    })

    # Origin (0,0) is at the top left corner of the cleaned image, 
    # such that x increases to the right, y increases downwards
    # For plotting, I want to show the location in the tank, so I modify x to match location in the tank
    # and y to be negative and descending downwards to be depth

    x_max = x.max()
    y_min = y.min()

    # Plot the velocity field
    fig, ax = plt.subplots(1, 2, figsize=(14,6))

    ax[0].imshow(cleaned_frames[key+1], cmap='gray_r', alpha=0.5, extent=(x.min(), x.max(), y.max(), y.min()))
    ax[1].imshow(cleaned_frames[key+1], cmap='gray_r', alpha=0.5, extent=(x.min(), x.max(), y.max(), y.min()))

    # Colorbar limits for vertical velocity
    vmin = -0.1
    vmax = 0.1
    
    # Colorbar limits for velocity magnitude
    umin = 0
    umax = 0.12

    step_x = 2
    step_z = 1

    # Filled contour of velocity magnitude
    im = ax[0].contourf(x, y, np.sqrt(u**2 + v**2), cmap=cm.imola, levels=np.linspace(umin, umax, 51), extend='max')
    # Quiver plot of velocity vectors, subsampled for better visibility
    im1 = ax[0].quiver(x[::step_z, ::step_x], y[::step_z, ::step_x], -u[::step_z, ::step_x], v[::step_z, ::step_x], color='white', scale=5)
    ax[0].hlines(y=plate_top_m, xmin=x.min(), xmax=x.max(), colors='black', linestyles='--', linewidth=1, label='Top of plates')
    cbar = plt.colorbar(im, label='Velocity magnitude (m/s)', shrink=0.8)
    ax[0].set_title(f't={timestamps[idx_b]:.3f} s')
    ax[0].grid()
    ax[0].legend(loc='lower left')

    step_z = 5
    step_x = 1
    # Filled contour plot of vertical velocity
    im1 = ax[1].contourf(x, y, v, cmap=cm.vik, levels=np.linspace(vmin, vmax, 51), extend='both')

    cbar3 = plt.colorbar(
    im1, extend='both',
    label='Vertical velocity (m/s)', shrink=0.8)

    ax[1].set_title(f't={timestamps[idx_b]:.3f} s')
    ax[1].grid()

    #ax[1].hlines(
    #y=y[y_idx_plate_top, :], xmin=x.min(), xmax=x.max(),
    #colors='gray', linewidth=0.5, linestyles='--',
    #label=rf'$\bar w$ = {w_bar[-1]:.4f} m/s')

    #ax[1].hlines(
    #y=y[y_idx_plate_top-1, :], xmin=x.min(), xmax=x.max(),
    #colors='gray', linewidth=0.5, linestyles='--',
    #label=rf'$\partial\bar w / \partial z$ = {dw_bar[-1]:.4f} m/s')

    #ax[1].fill_between(x[0, :], y[y_idx_plate_top-1, :], y[y_idx_plate_top, :], color='gray', alpha=0.3)

    ax[1].hlines(y=plate_top_m, xmin=x.min(), xmax=x.max(), colors='black', linestyles='--', linewidth=1, label=rf'$\bar w$ = {w_bar[-1]:.4f} m/s')
    ax[1].legend(loc='lower left')

    for a in ax:
        a.xaxis.set_major_formatter(FuncFormatter(x_phys_formatter))
        a.set_xlabel("x [m]")
        a.yaxis.set_major_formatter(FuncFormatter(depth_formatter))
        a.set_ylabel("z [m]")

    plt.savefig(f'/Users/kjesta/Desktop/LABDATA/PIV/Results/figs/f14a01/vel_field_{key}_r3.png', dpi=300)
    plt.close(fig)

    # Plot the vorticity and velocity gradients

    vmin = -0.1
    vmax = 0.1
    vlevs = np.linspace(vmin, vmax, 51)

    umin = -0.1
    umax = 0.1
    ulevs = np.linspace(umin, umax, 51)

    wmin = -0.01
    wmax = 0.01
    wlevs = np.linspace(wmin, wmax, 51)

    fig, ax = plt.subplots(1, 3, figsize=(18,6))
    im = ax[0].contourf(x, y, curl, alpha=0.5, levels=vlevs, cmap=cm.vik, extend='both')
    ax[0].imshow(cleaned_frames[key+1], cmap='gray_r', alpha=0.5,extent=(x.min(), x.max(), y.max(), y.min()))
    cbar = plt.colorbar(im, ax=ax[0], label='Vorticity (1/s)', shrink=0.7)
    ax[0].grid()

    im = ax[1].contourf(x, y, grad_u, alpha=0.5, cmap=cm.vik, levels=ulevs, extend='both')
    cbar = plt.colorbar(im, ax=ax[1], label=r'$\partial u / \partial x$ (1/s)', shrink=0.7)
    ax[1].imshow(cleaned_frames[key+1], cmap='gray_r', alpha=0.5, extent=(x.min(), x.max(), y.max(), y.min()))
    ax[1].grid()

    im = ax[2].contourf(x, y, grad_w, alpha=0.5, cmap=cm.vik, levels=wlevs, extend='both')
    cbar = plt.colorbar(im, ax=ax[2], label=r'$\partial w / \partial z$ (1/s)', shrink=0.7)
    ax[2].imshow(cleaned_frames[key+1], cmap='gray_r', alpha=0.5, extent=(x.min(), x.max(), y.max(), y.min()))
    ax[2].grid()
    fig.suptitle(f't = {timestamps[idx_b]:.3f} s', y=0.9)

    for a in ax:
        a.xaxis.set_major_formatter(FuncFormatter(x_phys_formatter))
        a.set_xlabel("x [m]")
        a.yaxis.set_major_formatter(FuncFormatter(depth_formatter))
        a.set_ylabel("z [m]")
        
    plt.tight_layout()  
    plt.savefig(f'/Users/kjesta/Desktop/LABDATA/PIV/Results/figs/f14a01/curl_grad_{key}_r3.png', dpi=300)
    plt.close(fig)

r3 = pd.DataFrame(results)
# Out:
# Total flagged fraction after all validations:  0.3278613771089831
# Total flagged fraction after all validations:  0.3378932968536252
# Total flagged fraction after all validations:  0.34655722754217966
# Total flagged fraction after all validations:  0.3333333333333333
# Total flagged fraction after all validations:  0.33105335157318744
# Total flagged fraction after all validations:  0.31053351573187415
# Total flagged fraction after all validations:  0.3438212494300046
# Total flagged fraction after all validations:  0.34154126766985865
# Total flagged fraction after all validations:  0.342453260373917
# Total flagged fraction after all validations:  0.3378932968536252
# Total flagged fraction after all validations:  0.34746922024623805
# Total flagged fraction after all validations:  0.34062927496580025
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.34610123119015046
# Total flagged fraction after all validations:  0.34199726402188785
# Total flagged fraction after all validations:  0.3328773369813042
# Total flagged fraction after all validations:  0.35658914728682173
# Total flagged fraction after all validations:  0.337437300501596
# Total flagged fraction after all validations:  0.3693570451436389
# Total flagged fraction after all validations:  0.35157318741450067
# Total flagged fraction after all validations:  0.37847697218422255
# Total flagged fraction after all validations:  0.35294117647058826
# Total flagged fraction after all validations:  0.3789329685362517
# Total flagged fraction after all validations:  0.37710898312813496
# Total flagged fraction after all validations:  0.36206110351117193
# Total flagged fraction after all validations:  0.36206110351117193
# Total flagged fraction after all validations:  0.3593251253989968
# Total flagged fraction after all validations:  0.36342909256725947
# Total flagged fraction after all validations:  0.34655722754217966
# Total flagged fraction after all validations:  0.34154126766985865
# Total flagged fraction after all validations:  0.3451892384860921
# Total flagged fraction after all validations:  0.34062927496580025
# Total flagged fraction after all validations:  0.3178294573643411
# Total flagged fraction after all validations:  0.3283173734610123
# Total flagged fraction after all validations:  0.3237574099407205
# Total flagged fraction after all validations:  0.3064295485636115
# Total flagged fraction after all validations:  0.3237574099407205
# Total flagged fraction after all validations:  0.3278613771089831
# Total flagged fraction after all validations:  0.3392612859097127
# Total flagged fraction after all validations:  0.332421340629275
# Total flagged fraction after all validations:  0.342453260373917
# Total flagged fraction after all validations:  0.3237574099407205
# Total flagged fraction after all validations:  0.33606931144550845
# Total flagged fraction after all validations:  0.3264933880528956
# Total flagged fraction after all validations:  0.3260373917008664
# Total flagged fraction after all validations:  0.32466940264477884
# Total flagged fraction after all validations:  0.34154126766985865
# Total flagged fraction after all validations:  0.3447332421340629
# Total flagged fraction after all validations:  0.3456452348381213
# Total flagged fraction after all validations:  0.3337893296853625
# Total flagged fraction after all validations:  0.34062927496580025
# Total flagged fraction after all validations:  0.337437300501596
# Total flagged fraction after all validations:  0.34655722754217966
# Total flagged fraction after all validations:  0.3278613771089831
# Total flagged fraction after all validations:  0.32512539899680803
# Total flagged fraction after all validations:  0.3315093479252166
# Total flagged fraction after all validations:  0.3287733698130415
# Total flagged fraction after all validations:  0.3392612859097127
# Total flagged fraction after all validations:  0.3333333333333333
# Total flagged fraction after all validations:  0.33059735522115824
# Total flagged fraction after all validations:  0.33606931144550845
# Total flagged fraction after all validations:  0.33652530779753764
# Total flagged fraction after all validations:  0.34062927496580025
# Total flagged fraction after all validations:  0.32147742818057456
# Total flagged fraction after all validations:  0.35294117647058826
# Total flagged fraction after all validations:  0.3342453260373917
# Total flagged fraction after all validations:  0.3538531691746466
# Total flagged fraction after all validations:  0.3392612859097127
# Total flagged fraction after all validations:  0.3442772457820337
# Total flagged fraction after all validations:  0.35613315093479253
# Total flagged fraction after all validations:  0.36662106703146374
# Total flagged fraction after all validations:  0.36342909256725947
# Total flagged fraction after all validations:  0.3711810305517556
# Total flagged fraction after all validations:  0.36753305973552214
# Total flagged fraction after all validations:  0.35658914728682173
# Total flagged fraction after all validations:  0.3679890560875513
# Total flagged fraction after all validations:  0.3684450524395805
# Total flagged fraction after all validations:  0.3844049247606019
# Total flagged fraction after all validations:  0.3812129502963976
# Total flagged fraction after all validations:  0.3652530779753762
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.36616507067943455
# Total flagged fraction after all validations:  0.35157318741450067
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.3625170998632011
# Total flagged fraction after all validations:  0.3438212494300046
# Total flagged fraction after all validations:  0.3378932968536252
# Total flagged fraction after all validations:  0.3260373917008664
# Total flagged fraction after all validations:  0.3479252165982672
# Total flagged fraction after all validations:  0.33014135886912904
# Total flagged fraction after all validations:  0.33515731874145005
# Total flagged fraction after all validations:  0.3333333333333333
# Total flagged fraction after all validations:  0.33515731874145005
# Total flagged fraction after all validations:  0.3369813041495668
# Total flagged fraction after all validations:  0.3287733698130415
# Total flagged fraction after all validations:  0.3378932968536252
# Total flagged fraction after all validations:  0.31919744642042863
# Total flagged fraction after all validations:  0.34610123119015046
# Total flagged fraction after all validations:  0.34746922024623805
# Total flagged fraction after all validations:  0.3456452348381213
# Total flagged fraction after all validations:  0.34199726402188785
# Total flagged fraction after all validations:  0.35567715458276333
# Total flagged fraction after all validations:  0.3401732786137711
# Total flagged fraction after all validations:  0.33652530779753764
# Total flagged fraction after all validations:  0.3401732786137711
# Total flagged fraction after all validations:  0.35841313269493846
# Total flagged fraction after all validations:  0.3506611947104423
# Total flagged fraction after all validations:  0.3506611947104423
# Total flagged fraction after all validations:  0.35294117647058826
# Total flagged fraction after all validations:  0.34701322389420886
# Total flagged fraction after all validations:  0.3533971728226174
# Total flagged fraction after all validations:  0.3319653442772458
# Total flagged fraction after all validations:  0.3679890560875513
# Total flagged fraction after all validations:  0.3657090743274054
# Total flagged fraction after all validations:  0.36388508891928867
# Total flagged fraction after all validations:  0.3702690378476972
# Total flagged fraction after all validations:  0.3629730962152303
# Total flagged fraction after all validations:  0.35613315093479253
# Total flagged fraction after all validations:  0.354765161878705
# Total flagged fraction after all validations:  0.35658914728682173
# Total flagged fraction after all validations:  0.36114911080711354
# Total flagged fraction after all validations:  0.33561331509347925
# Total flagged fraction after all validations:  0.3492932056543548
# Total flagged fraction after all validations:  0.3378932968536252
# Total flagged fraction after all validations:  0.3392612859097127
# Total flagged fraction after all validations:  0.34655722754217966
# Total flagged fraction after all validations:  0.3488372093023256
# Total flagged fraction after all validations:  0.35795713634290927
# Total flagged fraction after all validations:  0.3228454172366621
# Total flagged fraction after all validations:  0.33561331509347925
# Total flagged fraction after all validations:  0.3401732786137711
# Total flagged fraction after all validations:  0.33014135886912904
# Total flagged fraction after all validations:  0.34655722754217966
# Total flagged fraction after all validations:  0.3315093479252166
# Total flagged fraction after all validations:  0.3383492932056544
# Total flagged fraction after all validations:  0.3388052895576835
# Total flagged fraction after all validations:  0.34108527131782945
# Total flagged fraction after all validations:  0.3347013223894209
# Total flagged fraction after all validations:  0.34108527131782945
# Total flagged fraction after all validations:  0.3511171910624715
# Total flagged fraction after all validations:  0.3433652530779754
# Total flagged fraction after all validations:  0.3593251253989968
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.33652530779753764
# Total flagged fraction after all validations:  0.3319653442772458
# Total flagged fraction after all validations:  0.320109439124487
# Total flagged fraction after all validations:  0.3237574099407205
# Total flagged fraction after all validations:  0.3287733698130415
# Total flagged fraction after all validations:  0.32193342453260376
# Total flagged fraction after all validations:  0.3388052895576835
# Total flagged fraction after all validations:  0.3383492932056544
# Total flagged fraction after all validations:  0.35157318741450067
# Total flagged fraction after all validations:  0.3456452348381213
# Total flagged fraction after all validations:  0.3401732786137711
# Total flagged fraction after all validations:  0.36069311445508434
# Total flagged fraction after all validations:  0.36707706338349294
# Total flagged fraction after all validations:  0.3479252165982672
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.35522115823073414
# Total flagged fraction after all validations:  0.3488372093023256
# Total flagged fraction after all validations:  0.37254901960784315
# Total flagged fraction after all validations:  0.36342909256725947
# Total flagged fraction after all validations:  0.3602371181030552
# Total flagged fraction after all validations:  0.3629730962152303
# Total flagged fraction after all validations:  0.35202918376652986
# Total flagged fraction after all validations:  0.3625170998632011
# Total flagged fraction after all validations:  0.36753305973552214
# Total flagged fraction after all validations:  0.3392612859097127
# Total flagged fraction after all validations:  0.3337893296853625
# Total flagged fraction after all validations:  0.34154126766985865
# Total flagged fraction after all validations:  0.359781121751026
# Total flagged fraction after all validations:  0.3538531691746466
# Total flagged fraction after all validations:  0.3397172822617419
# Total flagged fraction after all validations:  0.35841313269493846
# Total flagged fraction after all validations:  0.3283173734610123
# Total flagged fraction after all validations:  0.33059735522115824
# Total flagged fraction after all validations:  0.3283173734610123
# Total flagged fraction after all validations:  0.32193342453260376
# Total flagged fraction after all validations:  0.3082535339717282
# Total flagged fraction after all validations:  0.31098951208390335
# Total flagged fraction after all validations:  0.32968536251709984
# Total flagged fraction after all validations:  0.3223894208846329
# Total flagged fraction after all validations:  0.3369813041495668
# Total flagged fraction after all validations:  0.3429092567259462
# Total flagged fraction after all validations:  0.3315093479252166
# Total flagged fraction after all validations:  0.3511171910624715
# Total flagged fraction after all validations:  0.31965344277245783
# Total flagged fraction after all validations:  0.34062927496580025
# Total flagged fraction after all validations:  0.359781121751026
# Total flagged fraction after all validations:  0.35248518011855906
# Total flagged fraction after all validations:  0.34746922024623805
# Total flagged fraction after all validations:  0.34108527131782945
# Total flagged fraction after all validations:  0.35248518011855906
# Total flagged fraction after all validations:  0.35704514363885087
# Total flagged fraction after all validations:  0.35020519835841313
# Total flagged fraction after all validations:  0.35567715458276333
# Total flagged fraction after all validations:  0.3743730050159599
# Total flagged fraction after all validations:  0.35795713634290927
# Total flagged fraction after all validations:  0.37163702690378475
# Total flagged fraction after all validations:  0.36616507067943455
# Total flagged fraction after all validations:  0.3693570451436389
# Total flagged fraction after all validations:  0.3588691290469676
# Total flagged fraction after all validations:  0.3652530779753762
# Total flagged fraction after all validations:  0.3761969904240766
# Total flagged fraction after all validations:  0.3652530779753762
# Total flagged fraction after all validations:  0.369813041495668
# Total flagged fraction after all validations:  0.35841313269493846
# Total flagged fraction after all validations:  0.359781121751026
# Total flagged fraction after all validations:  0.33105335157318744
# Total flagged fraction after all validations:  0.35248518011855906
# Total flagged fraction after all validations:  0.32968536251709984
# Total flagged fraction after all validations:  0.3333333333333333
# Total flagged fraction after all validations:  0.3447332421340629
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.33059735522115824
# Total flagged fraction after all validations:  0.3342453260373917
# Total flagged fraction after all validations:  0.3397172822617419
# Total flagged fraction after all validations:  0.3278613771089831
# Total flagged fraction after all validations:  0.3292293661650707
# Total flagged fraction after all validations:  0.3223894208846329
# Total flagged fraction after all validations:  0.3283173734610123
# Total flagged fraction after all validations:  0.3319653442772458
# Total flagged fraction after all validations:  0.3392612859097127
# Total flagged fraction after all validations:  0.31007751937984496
# Total flagged fraction after all validations:  0.3287733698130415
# Total flagged fraction after all validations:  0.3319653442772458
# Total flagged fraction after all validations:  0.3328773369813042
# Total flagged fraction after all validations:  0.332421340629275
# Total flagged fraction after all validations:  0.3388052895576835
# Total flagged fraction after all validations:  0.35613315093479253
# Total flagged fraction after all validations:  0.3429092567259462
# Total flagged fraction after all validations:  0.32740538075695397
# Total flagged fraction after all validations:  0.3264933880528956
# Total flagged fraction after all validations:  0.3292293661650707
# Total flagged fraction after all validations:  0.33059735522115824
# Total flagged fraction after all validations:  0.3397172822617419
# Total flagged fraction after all validations:  0.3141814865481076
# Total flagged fraction after all validations:  0.31874145006839943
# Total flagged fraction after all validations:  0.3319653442772458
# Total flagged fraction after all validations:  0.33561331509347925
# Total flagged fraction after all validations:  0.3433652530779754
# Total flagged fraction after all validations:  0.36707706338349294
# Total flagged fraction after all validations:  0.3702690378476972
# Total flagged fraction after all validations:  0.35841313269493846
# Total flagged fraction after all validations:  0.3593251253989968
# Total flagged fraction after all validations:  0.35020519835841313
# Total flagged fraction after all validations:  0.3739170086639307
# Total flagged fraction after all validations:  0.3492932056543548
# Total flagged fraction after all validations:  0.34974920200638393
# Total flagged fraction after all validations:  0.3789329685362517
# Total flagged fraction after all validations:  0.37163702690378475
# Total flagged fraction after all validations:  0.3657090743274054
# Total flagged fraction after all validations:  0.3743730050159599
# Total flagged fraction after all validations:  0.36206110351117193
# Total flagged fraction after all validations:  0.359781121751026
# Total flagged fraction after all validations:  0.36616507067943455
# Total flagged fraction after all validations:  0.3807569539443684
# Total flagged fraction after all validations:  0.35750113999088007
# Total flagged fraction after all validations:  0.3383492932056544
# Total flagged fraction after all validations:  0.35795713634290927
# Total flagged fraction after all validations:  0.3506611947104423
# Total flagged fraction after all validations:  0.34610123119015046
# Total flagged fraction after all validations:  0.3506611947104423
# Total flagged fraction after all validations:  0.35294117647058826
# Total flagged fraction after all validations:  0.3456452348381213
# Total flagged fraction after all validations:  0.35294117647058826

# %%
r3.to_csv('/Users/kjesta/Desktop/LABDATA/PIV/results/f14a01_res_r3.csv', index=False)
