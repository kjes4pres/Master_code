# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from sklearn.metrics import r2_score
from matplotlib.lines import Line2D

sys.path.append('/Users/kjesta/Desktop/LABDATA/Kjersti_100226/')
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/')
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Processed_files/')

from funcs import *
from processing_funcs import *
from analysis_funcs import *

import matplotlib.style as mplstyle
mplstyle.use(["ggplot", "fast"])

import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2

# For plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as mplstyle
mplstyle.use(['ggplot', 'fast'])

mpl.rcParams['figure.dpi'] = 200
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.titlesize'] = 14
mpl.rcParams['axes.labelsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12

from matplotlib.transforms import ScaledTranslation
from matplotlib.colors import LinearSegmentedColormap
from cmocean import cm as cmo
from matplotlib.lines import Line2D
from matplotlib.colors import Normalize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = {
    0.898: {
        0.149: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0149_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0149_p005_results.csv"),
        },
        0.299: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0299_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0299_p005_results.csv"),
        },
        0.453: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0453_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0453_p005_results.csv"),
        },
    },
    0.980: {
        0.149: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0149_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0149_p005_results.csv"),
        },
        0.295: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0295_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0295_p005_results.csv"),
        },
        0.443: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0443_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0443_p005_results.csv"),
        },
    },
    1.061: {
        0.149: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0149_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0149_p005_results.csv"),
        },
        0.295: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0295_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0295_p005_results.csv"),
        },
        0.449: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0449_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0449_p005_results.csv"),
        },
    },
    1.143: {
        0.148: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0148_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0148_p005_results.csv"),
        },
        0.295: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0295_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0295_p005_results.csv"),
        },
        0.443: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0443_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0443_p005_results.csv"),
        },
    },
    1.225: {
        0.152: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0152_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0152_p005_results.csv"),
        },
        0.299: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0299_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0299_p005_results.csv"),
        },
        0.471: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0471_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0471_p005_results.csv"),
        },
    },
    1.306: {
        0.152: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0152_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0152_p005_results.csv"),
        },
        0.302: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0302_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0302_p005_results.csv"),
        },
        0.372: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0372_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0372_p005_results.csv"),
        },
        0.461: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0461_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0461_p005_results.csv"),
        },
    },
    1.388: {
        0.147: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0147_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0147_p005_results.csv"),
        },
        0.285: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0285_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0285_p005_results.csv"),
        },
        0.378: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0378_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0378_p005_results.csv"),
        },
        0.468: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0468_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0468_p005_results.csv"),
        },
    },
    1.470: {
        0.147: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0147_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0147_p005_results.csv"),
        },
        0.296: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0296_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0296_p005_results.csv"),
        },
        0.382: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0382_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0382_p005_results.csv"),
        },
        0.459: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0459_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0459_p005_results.csv"),
        },
    },
}

# %%
D = 0.3  # total water depth (m)
H = 0.25 # height of the plates (m)

# %%
freqs = list(data.keys())
volts = []

for i in range(len(freqs)):
    volts.append(list(data[freqs[i]].keys()))

# %%
wavenumber = []

for f in freqs:
    wavenumber.append(estimate_wavenumber(f, D))

# %%
alpha_theo = []
alpha_weber = []

# Theoretical spatial damping coefficient for each wavenumber
# With 5 cm tall plates on 30 cm water depth
for k in wavenumber:
    al_theo, al_weber = spatial_damping_coefficient(k, D, H)
    alpha_theo.append(al_theo)
    alpha_weber.append(al_weber)

# %%
rows = []

for f, amps in data.items():         # outer: frequency
    for a, tags in amps.items():     # middle: amplitude
        for tag, df in tags.items(): # inner: None / "p005"
            for _, row in df.iterrows():
                if a < 0.2:
                    a_tag = 'low'
                if a >= 0.2 and a < 0.305:
                    a_tag = 'medium'
                if a >= 0.370 and a < 0.385:
                    a_tag = 'medium-high'
                if a >= 0.4:
                    a_tag = 'high'
                
                rows.append({
                    "frequency": f,
                    "volt": a,
                    "volt_level": a_tag,
                    "tag": tag,
                    "run": row["Run"],          # R1 / R2 / R3
                    "Amp_obs_P0": row["Amp_obs_P0"],
                    "Amp_obs_P1": row["Amp_obs_P1"],
                    "Amp_obs_P2": row["Amp_obs_P2"],
                    "Amp_obs_P3": row["Amp_obs_P3"],
                    "Alpha_obs": row["Alpha_obs"],
                    "P3_minus_P0": row["P3_minus_P0"],
                    "ak": row["Amp_obs_P0"]*estimate_wavenumber(f, 0.3),
                    "kH": estimate_wavenumber(f, 0.3)*0.3,
                    "R": robin_parameter(H=H, a=row['Amp_obs_P0'], k=estimate_wavenumber(f, D))
                })

df = pd.DataFrame(rows)

# %%
df
# Out:
#      frequency   volt volt_level   tag run  Amp_obs_P0  Amp_obs_P1  \
# 0        0.898  0.149        low  None  R1    0.006782    0.006664
# 1        0.898  0.149        low  None  R2    0.006795    0.006664
# 2        0.898  0.149        low  None  R3    0.006795    0.006659
# 3        0.898  0.149        low  p005  R1    0.006863    0.006771
# 4        0.898  0.149        low  p005  R2    0.006875    0.006765
# ..         ...    ...        ...   ...  ..         ...         ...
# 157      1.470  0.459       high  None  R2    0.033924    0.033772
# 158      1.470  0.459       high  None  R3    0.034040    0.034739
# 159      1.470  0.459       high  p005  R1    0.033260    0.033420
# 160      1.470  0.459       high  p005  R2    0.033725    0.033691
# 161      1.470  0.459       high  p005  R3    0.034306    0.034310
#
#      Amp_obs_P2  Amp_obs_P3  Alpha_obs  P3_minus_P0        ak        kH  \
# 0      0.006638    0.006548   0.007841    -0.000234  0.026624  1.177642
# 1      0.006624    0.006533   0.008889    -0.000262  0.026673  1.177642
# 2      0.006618    0.006523   0.009238    -0.000272  0.026674  1.177642
# 3      0.006606    0.006495   0.013277    -0.000368  0.026941  1.177642
# 4      0.006607    0.006493   0.013667    -0.000382  0.026986  1.177642
# ..          ...         ...        ...          ...       ...       ...
# 157    0.033644    0.034699  -0.004147     0.000775  0.298050  2.635770
# 158    0.033824    0.033959   0.001865    -0.000081  0.299073  2.635770
# 159    0.034138    0.032223   0.004693    -0.001037  0.292220  2.635770
# 160    0.034255    0.030765   0.017306    -0.002960  0.296305  2.635770
# 161    0.034165    0.029537   0.030437    -0.004770  0.301413  2.635770
#
#             R
# 0    0.000864
# 1    0.000865
# 2    0.000866
# 3    0.000874
# 4    0.000876
# ..        ...
# 157  0.001931
# 158  0.001937
# 159  0.001893
# 160  0.001919
# 161  0.001952
#
# [162 rows x 14 columns]

# %%
no_plates = df[df["tag"].isna()]
plates = df[df["tag"] == "p005"]

# %%
level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

fig, ax = plt.subplots(figsize=(10, 6))

for level, sub in no_plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["Alpha_obs"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["Alpha_obs"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))


#ax.hlines(0, freqs[0]-0.01, freqs[-1]+0.01, colors='gray', alpha=0.7, linestyles='--')

plt.xlabel('Frequency (Hz)')
plt.ylabel(r'Damping coefficient $\alpha$ (1/m)')
plt.title('Damping coefficient for 30cm water depth')

ax.legend(title="Voltage Level", ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

# %%
# Make sure you only keep the columns you need to avoid duplicate col names
cols_keep = ["frequency", "volt", "run", "volt_level", "Alpha_obs"]

np_df = no_plates[cols_keep].copy()
pl_df = plates[cols_keep].copy()

# Add suffixes to distinguish the two Alpha columns
np_df = np_df.rename(columns={"Alpha_obs": "Alpha_no"})
pl_df = pl_df.rename(columns={"Alpha_obs": "Alpha_pl"})

# Merge on frequency, volt, run (and optionally volt_level, but it should be consistent)
diff_df = pd.merge(
    np_df,
    pl_df,
    on=["frequency", "volt", "run", "volt_level"],
    how="inner"
)

# Compute difference: plates minus no plates
diff_df["Delta_alpha"] = diff_df["Alpha_pl"] - diff_df["Alpha_no"]

# %%
level_colors = {
    "low":         "C0",
    "medium":      "C1",
    "medium-high": "C2",
    "high":        "C3",
}

fig, ax = plt.subplots(figsize=(10, 6))

for level, sub in diff_df.groupby("volt_level"):
    ax.scatter(
        sub["frequency"],
        sub["Delta_alpha"],
        marker="o",
        label=f"{level}",
        color=level_colors.get(level, "gray"),
    )

ax.plot(freqs, alpha_theo, color='grey', linestyle='dashed', label='Theoretical α')

ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel(r"$\Delta\alpha$ (1/m)")
ax.set_title(f"Spatial damping coefficient with walls subtracted (D = {D} m)")

ax.legend(title="Voltage Level", ncol=2)
plt.minorticks_on()
plt.grid(which="major", linestyle="-", linewidth=0.5, color="gray")
plt.grid(which="minor", linestyle=":", linewidth=0.5, color="lightgray")

# %%
plt.plot(alpha_weber)
plt.plot(alpha_theo)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

for level, sub in no_plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["P3_minus_P0"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["P3_minus_P0"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))


y1 = 0.001
y2 = -0.001

xmin = 0.89
xmax = 1.5

plt.hlines(y1, xmin=xmin, xmax=xmax, colors='grey', linestyles='dashed')
plt.hlines(y2, xmin=xmin, xmax=xmax, colors='grey', linestyles='dashed')

x_fill = np.linspace(xmin, xmax, 50)
plt.fill_between(x_fill, y1, y2,
                 color='grey', alpha=0.2, edgecolor='none', zorder=0)

plt.legend(title='Voltage level', loc='lower left', ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

plt.xlabel('Frequency (Hz)')
plt.ylabel(r'Change in amplitude $\Delta A$ (m)')
plt.title(f'Change in amplitude from first to last probe (D = {D} m)')
# Out:
# Text(0.5, 1.0, 'Change in amplitude from first to last probe (D = 0.3 m)')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

for level, sub in no_plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["ak"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["ak"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))

ax.set_xlabel('Frequency (Hz)')
ax.set_ylabel('ak')
ax.set_title(f'Wave steepness (D={D} m depth)')
ax.legend(title='Voltage level', loc='upper left', ncol=2)

plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

for level, sub in no_plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["P3_minus_P0"]/sub["Amp_obs_P0"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["P3_minus_P0"]/sub["Amp_obs_P0"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))


y1 = 0.001/sub["Amp_obs_P0"].max()  # Example threshold for fractional change
y2 = -0.001/sub["Amp_obs_P0"].max()  # Example threshold for fractional change

xmin = freqs[0] - 0.05
xmax = freqs[-1] + 0.05

plt.hlines(y1, xmin=xmin, xmax=xmax, colors='grey', linestyles='dashed')
plt.hlines(y2, xmin=xmin, xmax=xmax, colors='grey', linestyles='dashed')

x_fill = np.linspace(xmin, xmax, 50)
plt.fill_between(x_fill, y1, y2,
                 color='grey', alpha=0.2, edgecolor='none', zorder=0)

plt.legend(title='Voltage level', loc='lower left', ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

plt.xlabel('Frequency (Hz)')
plt.ylabel(r'Change in amplitude $\Delta A / A_0$')
plt.title(f'Fractional change in amplitude from first to last probe (D = {D} m)')
# Out:
# Text(0.5, 1.0, 'Fractional change in amplitude from first to last probe (D = 0.3 m)')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

for level, sub in no_plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["ak"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["ak"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))

ax.set_xlabel('Frequency (Hz)')
ax.set_ylabel('ak')
ax.set_title(f'Wave steepness (D={D} m depth)')
ax.legend(title='Voltage level', loc='upper left', ncol=2)

plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

# %%
level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

fig, ax = plt.subplots(figsize=(10, 6))

for level, sub in no_plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["R"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates.groupby("volt_level"):
    ax.scatter(sub["frequency"], sub["R"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))


plt.xlabel('Frequency (Hz)')
plt.ylabel(r'Robin parameter $R$')
plt.title(f'Robin parameter for {D*100} cm water depth')

ax.legend(title="Voltage Level", ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

# %%
x_probe_pos = np.array([4.86, 6.69, 7.87, 9.15])

# %%
volts
# Out:
# [[0.149, 0.299, 0.453],
#  [0.149, 0.295, 0.443],
#  [0.149, 0.295, 0.449],
#  [0.148, 0.295, 0.443],
#  [0.152, 0.299, 0.471],
#  [0.152, 0.302, 0.372, 0.461],
#  [0.147, 0.285, 0.378, 0.468],
#  [0.147, 0.296, 0.382, 0.459]]

# %%
freqs = list(data.keys())
cond = [None, 'p005']

def plot_amp_profile(freq):
    if freq == 0.898:
        volt = volts[0]
    elif freq == 0.980:
        volt = volts[1]
    elif freq == 1.061:
        volt = volts[2]
    elif freq == 1.143:
        volt = volts[3]
    elif freq == 1.225:
        volt = volts[4]
    elif freq == 1.306:
        volt = volts[5]
    elif freq == 1.388:
        volt = volts[6]
    elif freq == 1.470:
        volt = volts[7]

    for v in volt:
        df_no = data[freq][v][None]
        df_p = data[freq][v]["p005"]

        # Extract amplitudes and normalize by first probe amplitude
        amps_no_r1 = np.array([df_no["Amp_obs_P0"][0], df_no["Amp_obs_P1"][0], df_no["Amp_obs_P2"][0], df_no["Amp_obs_P3"][0]])
        amps_no_r2 = np.array([df_no["Amp_obs_P0"][1], df_no["Amp_obs_P1"][1], df_no["Amp_obs_P2"][1], df_no["Amp_obs_P3"][1]])
        amps_no_r3 = np.array([df_no["Amp_obs_P0"][2], df_no["Amp_obs_P1"][2], df_no["Amp_obs_P2"][2], df_no["Amp_obs_P3"][2]])

        amps_p_r1 = np.array([df_p["Amp_obs_P0"][0], df_p["Amp_obs_P1"][0], df_p["Amp_obs_P2"][0], df_p["Amp_obs_P3"][0]])
        amps_p_r2 = np.array([df_p["Amp_obs_P0"][1], df_p["Amp_obs_P1"][1], df_p["Amp_obs_P2"][1], df_p["Amp_obs_P3"][1]])
        amps_p_r3 = np.array([df_p["Amp_obs_P0"][2], df_p["Amp_obs_P1"][2], df_p["Amp_obs_P2"][2], df_p["Amp_obs_P3"][2]])

        amps_r1_no_norm = amps_no_r1 / df_no["Amp_obs_P0"][0]
        amps_r2_no_norm = amps_no_r2 / df_no["Amp_obs_P0"][1]
        amps_r3_no_norm = amps_no_r3 / df_no["Amp_obs_P0"][2]

        amps_r1_p_norm = amps_p_r1 / df_p["Amp_obs_P0"][0]
        amps_r2_p_norm = amps_p_r2 / df_p["Amp_obs_P0"][1]
        amps_r3_p_norm = amps_p_r3 / df_p["Amp_obs_P0"][2]

        # Extract errors
        err_no_r1 = np.array([df_no['Amp_errors_P0'][0], df_no['Amp_errors_P1'][0], df_no['Amp_errors_P2'][0], df_no['Amp_errors_P3'][0]]) / df_no["Amp_obs_P0"][0]
        err_no_r2 = np.array([df_no['Amp_errors_P0'][1], df_no['Amp_errors_P1'][1], df_no['Amp_errors_P2'][1], df_no['Amp_errors_P3'][1]]) / df_no["Amp_obs_P0"][1]
        err_no_r3 = np.array([df_no['Amp_errors_P0'][2], df_no['Amp_errors_P1'][2], df_no['Amp_errors_P2'][2], df_no['Amp_errors_P3'][2]]) / df_no["Amp_obs_P0"][2]

        err_p_r1 = np.array([df_p['Amp_errors_P0'][0], df_p['Amp_errors_P1'][0], df_p['Amp_errors_P2'][0], df_p['Amp_errors_P3'][0]]) / df_p["Amp_obs_P0"][0]
        err_p_r2 = np.array([df_p['Amp_errors_P0'][1], df_p['Amp_errors_P1'][1], df_p['Amp_errors_P2'][1], df_p['Amp_errors_P3'][1]]) / df_p["Amp_obs_P0"][1]
        err_p_r3 = np.array([df_p['Amp_errors_P0'][2], df_p['Amp_errors_P1'][2], df_p['Amp_errors_P2'][2], df_p['Amp_errors_P3'][2]]) / df_p["Amp_obs_P0"][2]

        # Amplitude change
        delta_no_r1 = amps_no_r3 - amps_no_r1
        delta_no_r2 = amps_no_r3 - amps_no_r2
        delta_no_r3 = amps_no_r3 - amps_no_r3

        delta_p_r1 = amps_p_r3 - amps_p_r1
        delta_p_r2 = amps_p_r3 - amps_p_r2
        delta_p_r3 = amps_p_r3 - amps_p_r3  

        fig, ax = plt.subplots(figsize=(8, 5))
        ax.errorbar(x_probe_pos, amps_r1_no_norm, yerr=err_no_r1, fmt='o-', label='No plates', color='C0')
        ax.errorbar(x_probe_pos, amps_r2_no_norm, yerr=err_no_r2, fmt='o-', color='C0')
        ax.errorbar(x_probe_pos, amps_r3_no_norm, yerr=err_no_r3, fmt='o-', color='C0')
        ax.errorbar(x_probe_pos, amps_r1_p_norm, yerr=err_p_r1, fmt='s--', label='5 cm plates', color='C1')
        ax.errorbar(x_probe_pos, amps_r2_p_norm, yerr=err_p_r2, fmt='s--',  color='C1')
        ax.errorbar(x_probe_pos, amps_r3_p_norm, yerr=err_p_r3, fmt='s--',  color='C1')
        x_prof = x_probe_pos - x_probe_pos[0]  # Shift so that first probe is at x=0

        ax.plot(x_probe_pos, np.exp(-df_no["Alpha_obs"][0]*x_prof), color='gray', linestyle='dashed', label='Exp. decay (no plates)')
        ax.plot(x_probe_pos, np.exp(-df_p["Alpha_obs"][0]*x_prof), color='black', linestyle='dashed', label='Exp. decay (5 cm plates)')

        ax.set_xlabel('Distance from wave maker (m)')
        ax.set_ylabel('Normalized amplitude')
        ax.set_title(f'f={freq} Hz, A={v} V, D = {D} m')
        ax.legend(loc='lower left') 
        plt.minorticks_on()
        plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
        plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')
        plt.show()

# %%
plot_amp_profile(0.898)
