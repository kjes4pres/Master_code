# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from sklearn.metrics import r2_score
from matplotlib.lines import Line2D

sys.path.append('/Users/kjesta/Desktop/LABDATA/Kjersti_280126/')
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/')
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Processed_files/')

from funcs import *
from processing_funcs import *
from analysis_funcs import *

import matplotlib.style as mplstyle
mplstyle.use(["ggplot", "fast"])

import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
f11_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a01_results.csv')
f11_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a01_p005_results.csv')
f11_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a02_results.csv')
f11_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a02_p005_results.csv')
f11_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a03_results.csv')
f11_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a03_p005_results.csv')

# %%
f12_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a01_results.csv')
f12_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a01_p005_results.csv')
f12_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a02_results.csv')
f12_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a02_p005_results.csv')
f12_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a03_results.csv')
f12_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a03_p005_results.csv')

# %%
f13_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a01_results.csv')
f13_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a01_p005_results.csv')
f13_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a02_results.csv')
f13_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a02_p005_results.csv')
f13_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a03_results.csv')
f13_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a03_p005_results.csv')

# %%
f14_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a01_results.csv')
f14_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a01_p005_results.csv')
f14_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a02_results.csv')
f14_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a02_p005_results.csv')
f14_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a03_results.csv')
f14_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a03_p005_results.csv')

# %%
f15_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a01_results.csv')
f15_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a01_p005_results.csv')
f15_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a02_results.csv')
f15_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a02_p005_results.csv')
f15_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a03_results.csv')
f15_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a03_p005_results.csv')

# %%
f16_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a01_results.csv')
f16_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a01_p005_results.csv')
f16_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a02_results.csv')
f16_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a02_p005_results.csv')
f16_a025 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a025_results.csv')
f16_a025_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a025_p005_results.csv')
f16_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a03_results.csv')
f16_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a03_p005_results.csv')

# %%
f17_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a01_results.csv')
f17_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a01_p005_results.csv')
f17_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a02_results.csv')
f17_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a02_p005_results.csv')
f17_a025 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a025_results.csv')
f17_a025_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a025_p005_results.csv')
f17_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a03_results.csv')
f17_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a03_p005_results.csv')

# %%
f18_a01 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a01_results.csv')
f18_a01_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a01_p005_results.csv')
f18_a02 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a02_results.csv')
f18_a02_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a02_p005_results.csv')
f18_a025 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a025_results.csv')
f18_a025_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a025_p005_results.csv')
f18_a03 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a03_results.csv')
f18_a03_p005 = pd.read_csv('/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a03_p005_results.csv')

# %%
k_f11 = estimate_wavenumber(1.1, 0.2)
k_f12 = estimate_wavenumber(1.2, 0.2)
k_f13 = estimate_wavenumber(1.3, 0.2)
k_f14 = estimate_wavenumber(1.4, 0.2)
k_f15 = estimate_wavenumber(1.5, 0.2)
k_f16 = estimate_wavenumber(1.6, 0.2)
k_f17 = estimate_wavenumber(1.7, 0.2)
k_f18 = estimate_wavenumber(1.8, 0.2)

alpha_theo_f11 = spatial_damping_coefficient(k_f11, 0.2, 0.15)
alpha_theo_f12 = spatial_damping_coefficient(k_f12, 0.2, 0.15)
alpha_theo_f13 = spatial_damping_coefficient(k_f13, 0.2, 0.15)
alpha_theo_f14 = spatial_damping_coefficient(k_f14, 0.2, 0.15)
alpha_theo_f15 = spatial_damping_coefficient(k_f15, 0.2, 0.15)
alpha_theo_f16 = spatial_damping_coefficient(k_f16, 0.2, 0.15)
alpha_theo_f17 = spatial_damping_coefficient(k_f17, 0.2, 0.15)
alpha_theo_f18 = spatial_damping_coefficient(k_f18, 0.2, 0.15)

# %%
f11_a01
# Out:
#   Run  Alpha_obs  SE_Alpha_obs     T_val  Amp_obs_P0  Amp_obs_P1  Amp_obs_P2  \
# 0  R1   0.010959      0.000416  4.302653    0.004611    0.004522    0.004470
# 1  R2   0.010128      0.000568  4.302653    0.004599    0.004515    0.004472
# 2  R3   0.010580      0.000626  4.302653    0.004606    0.004508    0.004469
#
#    Amp_obs_P3  Amp_errors_P0  Amp_errors_P1  Amp_errors_P2  Amp_errors_P3  \
# 0    0.004397       0.000035        0.00004       0.000045       0.000052
# 1    0.004400       0.000035        0.00004       0.000045       0.000052
# 2    0.004396       0.000035        0.00004       0.000045       0.000052
#
#    P3_minus_P0
# 0    -0.000214
# 1    -0.000199
# 2    -0.000209

# %%
freqs1 = ['f11', 'f12', 'f13', 'f14', 'f15']
freqs2 = ['f16', 'f17', 'f18']
amps1 = ['a01', 'a02', 'a03']
amps2 = ['a01', 'a02', 'a025', 'a03']

obs_amp1 = []
obs_amp2 = []

for f in freqs1:
    for a in amps1:
        no = eval(f'{f}_{a}')
        obs_amp1.append(np.array([no['Amp_obs_P0'], no['Amp_obs_P1'], no['Amp_obs_P2'], no['Amp_obs_P3']]))

for f in freqs2:
    for a in amps2:
        no = eval(f'{f}_{a}')
        obs_amp2.append(np.array([no['Amp_obs_P0'], no['Amp_obs_P1'], no['Amp_obs_P2'], no['Amp_obs_P3']]))

obs_amp1_p = []
obs_amp2_p = []

for f in freqs1:
    for a in amps1:
        no = eval(f'{f}_{a}_p005')
        obs_amp1_p.append(np.array([no['Amp_obs_P0'], no['Amp_obs_P1'], no['Amp_obs_P2'], no['Amp_obs_P3']]))

for f in freqs2:
    for a in amps2:
        no = eval(f'{f}_{a}_p005')
        obs_amp2_p.append(np.array([no['Amp_obs_P0'], no['Amp_obs_P1'], no['Amp_obs_P2'], no['Amp_obs_P3']]))

obs_amp1 = np.array(obs_amp1)
obs_amp2 = np.array(obs_amp2)

# %%
np.shape(obs_amp1)
# Out:
# (15, 4, 3)

# %%
ak_a01_f11 = np.mean(obs_amp1[0, 0, :])*k_f11
ak_a02_f11 = np.mean(obs_amp1[1, 0, :])*k_f11
ak_a03_f11 = np.mean(obs_amp1[2, 0, :])*k_f11
ak_a01_f12 = np.mean(obs_amp1[3, 0, :])*k_f12
ak_a02_f12 = np.mean(obs_amp1[4, 0, :])*k_f12
ak_a03_f12 = np.mean(obs_amp1[5, 0, :])*k_f12
ak_a01_f13 = np.mean(obs_amp1[6, 0, :])*k_f13
ak_a02_f13 = np.mean(obs_amp1[7, 0, :])*k_f13
ak_a03_f13 = np.mean(obs_amp1[8, 0, :])*k_f13
ak_a01_f14 = np.mean(obs_amp1[9, 0, :])*k_f14
ak_a02_f14 = np.mean(obs_amp1[10, 0, :])*k_f14
ak_a03_f14 = np.mean(obs_amp1[11, 0, :])*k_f14
ak_a01_f15 = np.mean(obs_amp1[12, 0, :])*k_f15
ak_a02_f15 = np.mean(obs_amp1[13, 0, :])*k_f15
ak_a03_f15 = np.mean(obs_amp1[14, 0, :])*k_f15
ak_a01_f16 = np.mean(obs_amp2[0, 0, :])*k_f16
ak_a02_f16 = np.mean(obs_amp2[1, 0, :])*k_f16
ak_a025_f16 = np.mean(obs_amp2[2, 0, :])*k_f16
ak_a03_f16 = np.mean(obs_amp2[3, 0, :])* k_f16
ak_a01_f17 = np.mean(obs_amp2[4, 0, :])*k_f17
ak_a02_f17 = np.mean(obs_amp2[5, 0, :])*k_f17
ak_a025_f17 = np.mean(obs_amp2[6, 0, :])*k_f17
ak_a03_f17 = np.mean(obs_amp2[7, 0, :])* k_f17
ak_a01_f18 = np.mean(obs_amp2[8, 0, :])*k_f18
ak_a02_f18 = np.mean(obs_amp2[9, 0, :])*k_f18
ak_a025_f18 = np.mean(obs_amp2[10, 0, :])*k_f18
ak_a03_f18 = np.mean(obs_amp2[11, 0, :])* k_f18

ak1 = [ak_a01_f11, ak_a02_f11, ak_a03_f11,
      ak_a01_f12, ak_a02_f12, ak_a03_f12,
      ak_a01_f13, ak_a02_f13, ak_a03_f13,
      ak_a01_f14, ak_a02_f14, ak_a03_f14,
      ak_a01_f15, ak_a02_f15, ak_a03_f15]
ak2 = [ak_a01_f16, ak_a02_f16, ak_a025_f16, ak_a03_f16,
      ak_a01_f17, ak_a02_f17, ak_a025_f17, ak_a03_f17,
      ak_a01_f18, ak_a02_f18, ak_a025_f18, ak_a03_f18]

# %%
freqs1 = ['f11', 'f12', 'f13', 'f14', 'f15']
freqs2 = ['f16', 'f17', 'f18']
amps1 = ['a01', 'a02', 'a03']
amps2 = ['a01', 'a02', 'a025', 'a03']

damp_coeffs1 = []
damp_coeffs2 = []

for f in freqs1:
    for a in amps1:
        no = eval(f'{f}_{a}')
        damp_coeffs1.append(np.mean(no['Alpha_obs'].values))

for f in freqs2:
    for a in amps2:
        no = eval(f'{f}_{a}')
        damp_coeffs2.append(np.mean(no['Alpha_obs'].values))

damp_coeffs1_p = []
damp_coeffs2_p = []

for f in freqs1:
    for a in amps1:
        no = eval(f'{f}_{a}_p005')
        damp_coeffs1_p.append(np.mean(no['Alpha_obs'].values))

for f in freqs2:
    for a in amps2:
        no = eval(f'{f}_{a}_p005')
        damp_coeffs2_p.append(np.mean(no['Alpha_obs'].values))

# %%
num_freqs1 = [1.1, 1.1, 1.1,
              1.2, 1.2, 1.2,
              1.3, 1.3, 1.3,
              1.4, 1.4, 1.4,
              1.5, 1.5, 1.5]
num_freqs2 = [1.6, 1.6, 1.6, 1.6,
              1.7, 1.7, 1.7, 1.7,
              1.8, 1.8, 1.8, 1.8]

plt.plot(num_freqs1[0::3], damp_coeffs1[0::3], color='C0', linestyle='None', marker='o')
plt.plot(num_freqs1[1::3], damp_coeffs1[1::3], color='C1', linestyle='None', marker='o')
plt.plot(num_freqs1[2::3], damp_coeffs1[2::3], color='C2', linestyle='None', marker='o')

plt.plot(num_freqs2[0::4], damp_coeffs2[0::4], color='C0', linestyle='None', marker='o', label='0.1V - no plates')
plt.plot(num_freqs2[1::4], damp_coeffs2[1::4], color='C1', linestyle='None', marker='o', label='0.2V - no plates')
plt.plot(num_freqs2[2::4], damp_coeffs2[2::4], color='C3', linestyle='None', marker='o', label='0.25V - no plates')
plt.plot(num_freqs2[3::4], damp_coeffs2[3::4], color='C2', linestyle='None', marker='o', label='0.3V - no plates')

plt.plot(num_freqs1[0::3], damp_coeffs1_p[0::3], color='C0', linestyle='None', marker='x')
plt.plot(num_freqs1[1::3], damp_coeffs1_p[1::3], color='C1', linestyle='None', marker='x')
plt.plot(num_freqs1[2::3], damp_coeffs1_p[2::3], color='C2', linestyle='None', marker='x')

plt.plot(num_freqs2[0::4], damp_coeffs2_p[0::4], color='C0', linestyle='None', marker='x', label='0.1V - with 5cm plates')
plt.plot(num_freqs2[1::4], damp_coeffs2_p[1::4], color='C1', linestyle='None', marker='x', label='0.2V - with 5cm plates')
plt.plot(num_freqs2[2::4], damp_coeffs2_p[2::4], color='C3', linestyle='None', marker='x', label='0.25V - with 5cm plates')
plt.plot(num_freqs2[3::4], damp_coeffs2_p[3::4], color='C2', linestyle='None', marker='x', label='0.3V - with 5cm plates')

plt.legend(ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

plt.xlabel('Frequency (Hz)')
plt.ylabel(r'Damping coefficient $\alpha$ (1/m)')
plt.title('Damping coefficient for 20cm water depth')
# Out:
# Text(0.5, 1.0, 'Damping coefficient for 20cm water depth')

# %%
damp_plates1 = np.array(damp_coeffs1_p) - np.array(damp_coeffs1)
damp_plates2 = np.array(damp_coeffs2_p) - np.array(damp_coeffs2)

# %%
plt.plot(num_freqs1[0::3], damp_plates1[0::3], color='C0', linestyle='None', marker='o')
plt.plot(num_freqs1[1::3], damp_plates1[1::3], color='C1', linestyle='None', marker='o')
plt.plot(num_freqs1[2::3], damp_plates1[2::3], color='C2', linestyle='None', marker='o')

plt.plot(num_freqs2[0::4], damp_plates2[0::4], color='C0', linestyle='None', marker='o', label='A=0.1V')
plt.plot(num_freqs2[1::4], damp_plates2[1::4], color='C1', linestyle='None', marker='o', label='A=0.2V')
plt.plot(num_freqs2[2::4], damp_plates2[2::4], color='C3', linestyle='None', marker='o', label='A=0.25V')
plt.plot(num_freqs2[3::4], damp_plates2[3::4], color='C2', linestyle='None', marker='o', label='A=0.3V')

plt.hlines(alpha_theo_f11, xmin=1.05, xmax=1.15, colors='grey', linestyles='dashed', label='Theoretical α')
plt.hlines(alpha_theo_f12, xmin=1.15, xmax=1.25, colors='grey', linestyles='dashed')
plt.hlines(alpha_theo_f13, xmin=1.25, xmax=1.35, colors='grey', linestyles='dashed')  
plt.hlines(alpha_theo_f14, xmin=1.35, xmax=1.45, colors='grey', linestyles='dashed')
plt.hlines(alpha_theo_f15, xmin=1.45, xmax=1.55, colors='grey', linestyles='dashed')
plt.hlines(alpha_theo_f16, xmin=1.55, xmax=1.65, colors='grey', linestyles='dashed')
plt.hlines(alpha_theo_f17, xmin=1.65, xmax=1.75, colors='grey', linestyles='dashed')
plt.hlines(alpha_theo_f18, xmin=1.75, xmax=1.85, colors='grey', linestyles='dashed')

plt.xlabel('Frequency (Hz)')
plt.ylabel('Damping coefficient α (1/m)')
plt.legend(ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

plt.title('Damping coefficient with walls subtracted')
# Out:
# Text(0.5, 1.0, 'Damping coefficient with walls subtracted')

# %%
freqs1 = ['f11', 'f12', 'f13', 'f14', 'f15']
freqs2 = ['f16', 'f17', 'f18']
amps1 = ['a01', 'a02', 'a03']
amps2 = ['a01', 'a02', 'a025', 'a03']

change_amp1 = []
change_amp2 = []

for f in freqs1:
    for a in amps1:
        no = eval(f'{f}_{a}')
        change_amp1.append(np.mean(no['P3_minus_P0'].values))

for f in freqs2:
    for a in amps2:
        no = eval(f'{f}_{a}')
        change_amp2.append(np.mean(no['P3_minus_P0'].values))

change_amp1_p = []
change_amp2_p = []

for f in freqs1:
    for a in amps1:
        no = eval(f'{f}_{a}_p005')
        change_amp1_p.append(np.mean(no['P3_minus_P0'].values))

for f in freqs2:
    for a in amps2:
        no = eval(f'{f}_{a}_p005')
        change_amp2_p.append(np.mean(no['P3_minus_P0'].values))

# %%
num_freqs1 = [1.1, 1.1, 1.1,
              1.2, 1.2, 1.2,
              1.3, 1.3, 1.3,
              1.4, 1.4, 1.4,
              1.5, 1.5, 1.5]
num_freqs2 = [1.6, 1.6, 1.6, 1.6,
              1.7, 1.7, 1.7, 1.7,
              1.8, 1.8, 1.8, 1.8]

plt.plot(num_freqs1[0::3], change_amp1[0::3], color='C0', linestyle='None', marker='o')
plt.plot(num_freqs1[1::3], change_amp1[1::3], color='C1', linestyle='None', marker='o')
plt.plot(num_freqs1[2::3], change_amp1[2::3], color='C2', linestyle='None', marker='o')

plt.plot(num_freqs2[0::4], change_amp2[0::4], color='C0', linestyle='None', marker='o', label='0.1V - no plates')
plt.plot(num_freqs2[1::4], change_amp2[1::4], color='C1', linestyle='None', marker='o', label='0.2V - no plates')
plt.plot(num_freqs2[2::4], change_amp2[2::4], color='C3', linestyle='None', marker='o', label='0.25V - no plates')
plt.plot(num_freqs2[3::4], change_amp2[3::4], color='C2', linestyle='None', marker='o', label='0.3V - no plates')

plt.plot(num_freqs1[0::3], change_amp1_p[0::3], color='C0', linestyle='None', marker='x')
plt.plot(num_freqs1[1::3], change_amp1_p[1::3], color='C1', linestyle='None', marker='x')
plt.plot(num_freqs1[2::3], change_amp1_p[2::3], color='C2', linestyle='None', marker='x')

plt.plot(num_freqs2[0::4], change_amp2_p[0::4], color='C0', linestyle='None', marker='x', label='0.1V - with 5cm plates')
plt.plot(num_freqs2[1::4], change_amp2_p[1::4], color='C1', linestyle='None', marker='x', label='0.2V - with 5cm plates')
plt.plot(num_freqs2[2::4], change_amp2_p[2::4], color='C3', linestyle='None', marker='x', label='0.25V - with 5cm plates')
plt.plot(num_freqs2[3::4], change_amp2_p[3::4], color='C2', linestyle='None', marker='x', label='0.3V - with 5cm plates')

y1 = 0.001
y2 = -0.001
xmin = 1.09
xmax = 1.81
plt.hlines(y1, xmin=xmin, xmax=xmax, colors='grey', linestyles='dashed')
plt.hlines(y2, xmin=xmin, xmax=xmax, colors='grey', linestyles='dashed')

x_fill = np.linspace(xmin, xmax, 50)
plt.fill_between(x_fill, y1, y2,
                 color='grey', alpha=0.2, edgecolor='none', zorder=0)

plt.legend(loc='lower left', ncol=2)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

plt.xlabel('Frequency (Hz)')
plt.ylabel(r'Change in amplitude $\Delta A$ (m)')
plt.title('Change in amplitude from first to last probe')
# Out:
# Text(0.5, 1.0, 'Change in amplitude from first to last probe')

# %%
plt.scatter(ak1, change_amp1)
plt.scatter(ak2, change_amp2)
plt.scatter(ak1, change_amp1_p)
plt.scatter(ak2, change_amp2_p)
