# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from sklearn.metrics import r2_score
from matplotlib.lines import Line2D

sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/')
from funcs import *
from processing_funcs import *
from theoretical import *
from analysis_funcs import *

import matplotlib.style as mplstyle
mplstyle.use(["ggplot", "fast"])

import warnings
warnings.filterwarnings("ignore")

sys.path.append('/Users/kjesta/Desktop/LABDATA/Kjersti_260126/')

#figpath = '/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/No plates/20cm/Figures/'

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Reading in the pre-processed files
#
# The files are cleaned, detrended, corrected for outliers and later combined as the mean of three consecutive runs per experiment.

# %%
# f = 1.1 Hz
# Empty tank
f1_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f11_a01_processed.csv')
f1_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f11_a02_processed.csv')
f1_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f11_a03_processed.csv')

# With 5 cm tall plates
f1_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f11_a01_p005_processed.csv')
f1_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f11_a02_p005_processed.csv')
f1_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f11_a03_p005_processed.csv')

# With 10 cm tall plates

# f = 1.2 Hz
# Empty tank
f2_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f12_a01_processed.csv')
f2_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f12_a02_processed.csv')
f2_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f12_a03_processed.csv')

# With 5 cm tall plates
f2_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f12_a01_p005_processed.csv')
f2_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f12_a02_p005_processed.csv')
f2_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f12_a03_p005_processed.csv')

# With 10 cm tall plates

# f = 1.3 Hz
# Empty tank
f3_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f13_a01_processed.csv')
f3_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f13_a02_processed.csv')
f3_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f13_a03_processed.csv')

# With 5 cm tall plates
f3_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f13_a01_p005_processed.csv')
f3_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f13_a02_p005_processed.csv')
f3_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f13_a03_p005_processed.csv')

# With 10 cm tall plates

# f = 1.4 Hz
# Empty tank
f4_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f14_a01_processed.csv')
f4_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f14_a02_processed.csv')
f4_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f14_a03_processed.csv')
# With 5 cm tall plates
f4_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f14_a01_p005_processed.csv')
f4_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f14_a02_p005_processed.csv')
f4_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f14_a03_p005_processed.csv')

# With 10 cm tall plates

# f = 1.5 Hz
# Empty tank
f5_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f15_a01_processed.csv')
f5_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f15_a02_processed.csv')
f5_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f15_a03_processed.csv')
# With 5 cm tall plates
f5_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f15_a01_p005_processed.csv')
f5_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f15_a02_p005_processed.csv')
f5_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f15_a03_p005_processed.csv')
# With 10 cm tall plates

# f = 1.6 Hz
# Empty tank
f6_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a01_processed.csv')
f6_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a02_processed.csv')
f6_a25 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a025_processed.csv')
f6_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a03_processed.csv')
# With 5 cm tall plates
f6_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a01_p005_processed.csv')
f6_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a02_p005_processed.csv')
f6_a25_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a025_p005_processed.csv')
f6_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f16_a03_p005_processed.csv')
# With 10 cm tall plates

# f = 1.7 Hz
# Empty tank
f7_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a01_processed.csv')
f7_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a02_processed.csv')
f7_a25 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a025_processed.csv')
f7_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a03_processed.csv')
# With 5 cm tall plates
f7_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a01_p005_processed.csv')
f7_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a02_p005_processed.csv')
f7_a25_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a025_p005_processed.csv')
f7_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f17_a03_p005_processed.csv')
# With 10 cm tall plates

# f = 1.8 Hz
# Empty tank
f8_a1 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a01_processed.csv')
f8_a2 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a02_processed.csv')
f8_a25 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a025_processed.csv')
f8_a3 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a03_processed.csv')
# With 5 cm tall plates
f8_a1_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a01_p005_processed.csv')
f8_a2_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a02_p005_processed.csv')
f8_a25_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a025_p005_processed.csv')
f8_a3_p005 = pd.read_csv('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/Results/Processed_files/20cm_f18_a03_p005_processed.csv')
# With 10 cm tall plates

# %%
x_probe_pos = np.array([4.86, 6.69, 7.87, 9.15])  # Base positions, meters from wave maker

plate_pos = np.array([6.34, 9.38])  # Positions of the plates, meters from wave maker

# %%
amp_f1_a1, err_f1_a1 = get_amp_n_err_lists(f1_a1)
amp_f1_a1_p005, err_f1_a1_p005 = get_amp_n_err_lists(f1_a1_p005)
amp_f1_a2, err_f1_a2 = get_amp_n_err_lists(f1_a2)
amp_f1_a2_p005, err_f1_a2_p005 = get_amp_n_err_lists(f1_a2_p005)
amp_f1_a3, err_f1_a3 = get_amp_n_err_lists(f1_a3)
amp_f1_a3_p005, err_f1_a3_p005 = get_amp_n_err_lists(f1_a3_p005)

amp_f2_a1, err_f2_a1 = get_amp_n_err_lists(f2_a1)
amp_f2_a1_p005, err_f2_a1_p005 = get_amp_n_err_lists(f2_a1_p005)
amp_f2_a2, err_f2_a2 = get_amp_n_err_lists(f2_a2)
amp_f2_a2_p005, err_f2_a2_p005 = get_amp_n_err_lists(f2_a2_p005)
amp_f2_a3, err_f2_a3 = get_amp_n_err_lists(f2_a3)
amp_f2_a3_p005, err_f2_a3_p005 = get_amp_n_err_lists(f2_a3_p005)

amp_f3_a1, err_f3_a1 = get_amp_n_err_lists(f3_a1)
amp_f3_a1_p005, err_f3_a1_p005 = get_amp_n_err_lists(f3_a1_p005)
amp_f3_a2, err_f3_a2 = get_amp_n_err_lists(f3_a2)
amp_f3_a2_p005, err_f3_a2_p005 = get_amp_n_err_lists(f3_a2_p005)
amp_f3_a3, err_f3_a3 = get_amp_n_err_lists(f3_a3)
amp_f3_a3_p005, err_f3_a3_p005 = get_amp_n_err_lists(f3_a3_p005)

amp_f4_a1, err_f4_a1 = get_amp_n_err_lists(f4_a1)
amp_f4_a1_p005, err_f4_a1_p005 = get_amp_n_err_lists(f4_a1_p005)
amp_f4_a2, err_f4_a2 = get_amp_n_err_lists(f4_a2)
amp_f4_a2_p005, err_f4_a2_p005 = get_amp_n_err_lists(f4_a2_p005)
amp_f4_a3, err_f4_a3 = get_amp_n_err_lists(f4_a3)
amp_f4_a3_p005, err_f4_a3_p005 = get_amp_n_err_lists(f4_a3_p005)

amp_f5_a1, err_f5_a1 = get_amp_n_err_lists(f5_a1)
amp_f5_a1_p005, err_f5_a1_p005 = get_amp_n_err_lists(f5_a1_p005)
amp_f5_a2, err_f5_a2 = get_amp_n_err_lists(f5_a2)
amp_f5_a2_p005, err_f5_a2_p005 = get_amp_n_err_lists(f5_a2_p005)
amp_f5_a3, err_f5_a3 = get_amp_n_err_lists(f5_a3)
amp_f5_a3_p005, err_f5_a3_p005 = get_amp_n_err_lists(f5_a3_p005)

amp_f6_a1, err_f6_a1 = get_amp_n_err_lists(f6_a1)
amp_f6_a1_p005, err_f6_a1_p005 = get_amp_n_err_lists(f6_a1_p005)
amp_f6_a2, err_f6_a2 = get_amp_n_err_lists(f6_a2)
amp_f6_a2_p005, err_f6_a2_p005 = get_amp_n_err_lists(f6_a2_p005)
amp_f6_a25, err_f6_a25 = get_amp_n_err_lists(f6_a25)
amp_f6_a25_p005, err_f6_a25_p005 = get_amp_n_err_lists(f6_a25_p005)
amp_f6_a3, err_f6_a3 = get_amp_n_err_lists(f6_a3)
amp_f6_a3_p005, err_f6_a3_p005 = get_amp_n_err_lists(f6_a3_p005)

amp_f7_a1, err_f7_a1 = get_amp_n_err_lists(f7_a1)
amp_f7_a1_p005, err_f7_a1_p005 = get_amp_n_err_lists(f7_a1_p005)
amp_f7_a2, err_f7_a2 = get_amp_n_err_lists(f7_a2)
amp_f7_a2_p005, err_f7_a2_p005 = get_amp_n_err_lists(f7_a2_p005)
amp_f7_a25, err_f7_a25 = get_amp_n_err_lists(f7_a25)
amp_f7_a25_p005, err_f7_a25_p005 = get_amp_n_err_lists(f7_a25_p005)
amp_f7_a3, err_f7_a3 = get_amp_n_err_lists(f7_a3)
amp_f7_a3_p005, err_f7_a3_p005 = get_amp_n_err_lists(f7_a3_p005)

amp_f8_a1, err_f8_a1 = get_amp_n_err_lists(f8_a1)
amp_f8_a1_p005, err_f8_a1_p005 = get_amp_n_err_lists(f8_a1_p005)
amp_f8_a2, err_f8_a2 = get_amp_n_err_lists(f8_a2)
amp_f8_a2_p005, err_f8_a2_p005 = get_amp_n_err_lists(f8_a2_p005)
amp_f8_a25, err_f8_a25 = get_amp_n_err_lists(f8_a25)
amp_f8_a25_p005, err_f8_a25_p005 = get_amp_n_err_lists(f8_a25_p005)
amp_f8_a3, err_f8_a3 = get_amp_n_err_lists(f8_a3)
amp_f8_a3_p005, err_f8_a3_p005 = get_amp_n_err_lists(f8_a3_p005)

# %%
""" # Plotting
fig, ax = plt.subplots(3, 1, figsize=(8, 12), constrained_layout=True)

# A = 0.1 V
ax[0].errorbar(x_probe_pos,
            amp_f1_a1,
            yerr=err_f1_a1,
            fmt='o',
            ecolor='grey',
            elinewidth=1,
            capsize=3)

ax[0].errorbar(x_probe_pos,
            amp_f1_a1_p005,
            yerr=err_f1_a1_p005,
            fmt='o',
            ecolor='grey',
            elinewidth=1,
            capsize=3)

# A = 0.2 V
ax[1].errorbar(x_probe_pos,
            amp_f1_a2,
            yerr=err_f1_a2,
            fmt='o',
            ecolor='grey',
            elinewidth=1,
            capsize=3)

ax[1].errorbar(x_probe_pos,
               amp_f1_a2_p005,
               yerr=err_f1_a2_p005,
               fmt='o',
               ecolor='grey',
               elinewidth=1,
               capsize=3)

# A = 0.3 V
ax[2].errorbar(x_probe_pos,
            amp_f1_a3,
            yerr=err_f1_a3,
            fmt='o',
            ecolor='grey',
            elinewidth=1,
            capsize=3)

ax[2].errorbar(x_probe_pos,
               amp_f1_a3_p005,
               yerr=err_f1_a3_p005,
               fmt='o',
               ecolor='grey',
               elinewidth=1,
               capsize=3)

for axs in ax:
    axs.axvline(x=plate_pos[0], color='0.5', linestyle=':')
    axs.axvline(x=plate_pos[1], color='0.5', linestyle=':')
    axs.grid(which='minor', linestyle=':', linewidth='0.5', color='white')
    axs.minorticks_on()
    axs.set_xlabel('Probe Position (m)', fontsize=12)
    axs.set_ylabel('Amplitude (m)', fontsize=12)
    axs.legend(fontsize=10, loc='upper right')

ax[0].set_title(f'f = 1.1 Hz, A = 0.1 V', fontsize=12)
ax[1].set_title(f'f = 1.1 Hz, A = 0.2 V', fontsize=12)
ax[2].set_title(f'f = 1.1 Hz, A = 0.3 V', fontsize=12)

handles = [Line2D([0], [0], linestyle=None, color='C0', lw=2, label='Without plates'),
           Line2D([0], [0], linestyle=None, color='C1', lw=2, label='With plates')]

fig.legend(handles=handles, loc='upper left', fontsize=12, bbox_to_anchor=(0.1, 1.05)) """
# Out:
# " # Plotting\nfig, ax = plt.subplots(3, 1, figsize=(8, 12), constrained_layout=True)\n\n# A = 0.1 V\nax[0].errorbar(x_probe_pos,\n            amp_f1_a1,\n            yerr=err_f1_a1,\n            fmt='o',\n            ecolor='grey',\n            elinewidth=1,\n            capsize=3)\n\nax[0].errorbar(x_probe_pos,\n            amp_f1_a1_p005,\n            yerr=err_f1_a1_p005,\n            fmt='o',\n            ecolor='grey',\n            elinewidth=1,\n            capsize=3)\n\n# A = 0.2 V\nax[1].errorbar(x_probe_pos,\n            amp_f1_a2,\n            yerr=err_f1_a2,\n            fmt='o',\n            ecolor='grey',\n            elinewidth=1,\n            capsize=3)\n\nax[1].errorbar(x_probe_pos,\n               amp_f1_a2_p005,\n               yerr=err_f1_a2_p005,\n               fmt='o',\n               ecolor='grey',\n               elinewidth=1,\n               capsize=3)\n\n# A = 0.3 V\nax[2].errorbar(x_probe_pos,\n            amp_f1_a3,\n            yerr=err_f1_a3,\n           
# ...

# %%
k_f1 = estimate_wavenumber(freq=1.1, depth=0.2)

alpha_theo_f1 = spatial_damping_coefficient(k=k_f1, D=0.2, H=0.15)

alpha_obs_f1_a1= get_obs_alpha(amp_f1_a1, x_probe_pos)
alpha_obs_f1_a1_p005 = get_obs_alpha(amp_f1_a1_p005, x_probe_pos)
alpha_obs_f1_a2 = get_obs_alpha(amp_f1_a2, x_probe_pos)
alpha_obs_f1_a2_p005 = get_obs_alpha(amp_f1_a2_p005, x_probe_pos)
alpha_obs_f1_a3 = get_obs_alpha(amp_f1_a3, x_probe_pos)
alpha_obs_f1_a3_p005 = get_obs_alpha(amp_f1_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.1 Hz): ', f'{alpha_theo_f1:.4f}\n')
print('Observed spatial damping coefficients (f=1.1 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f1_a1[0]:.4f}, with plates: {alpha_obs_f1_a1_p005[0]:.4f}, due to plates: {alpha_obs_f1_a1_p005[0]-alpha_obs_f1_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f1_a2[0]:.4f}, with plates: {alpha_obs_f1_a2_p005[0]:.4f}, due to plates: {alpha_obs_f1_a2_p005[0]-alpha_obs_f1_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f1_a3[0]:.4f}, with plates: {alpha_obs_f1_a3_p005[0]:.4f}, due to plates: {alpha_obs_f1_a3_p005[0]-alpha_obs_f1_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.1 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.1 Hz):
#  A=0.1 V, no plates: 0.0105, with plates: 0.0277, due to plates: 0.0171
#  A=0.2 V, no plates: 0.0106, with plates: 0.0270, due to plates: 0.0164
#  A=0.3 V, no plates: 0.0107, with plates: 0.0267, due to plates: 0.0160

# %%
k_f2 = estimate_wavenumber(freq=1.2, depth=0.2)

alpha_theo_f2 = spatial_damping_coefficient(k=k_f2, D=0.2, H=0.15)

alpha_obs_f2_a1= get_obs_alpha(amp_f2_a1, x_probe_pos)
alpha_obs_f2_a1_p005 = get_obs_alpha(amp_f2_a1_p005, x_probe_pos)
alpha_obs_f2_a2 = get_obs_alpha(amp_f2_a2, x_probe_pos)
alpha_obs_f2_a2_p005 = get_obs_alpha(amp_f2_a2_p005, x_probe_pos)
alpha_obs_f2_a3 = get_obs_alpha(amp_f2_a3, x_probe_pos)
alpha_obs_f2_a3_p005 = get_obs_alpha(amp_f2_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.2 Hz): ', f'{alpha_theo_f2:.4f}\n')
print('Observed spatial damping coefficients (f=1.2 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f2_a1[0]:.4f}, with plates: {alpha_obs_f2_a1_p005[0]:.4f}, due to plates: {alpha_obs_f2_a1_p005[0]-alpha_obs_f2_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f2_a2[0]:.4f}, with plates: {alpha_obs_f2_a2_p005[0]:.4f}, due to plates: {alpha_obs_f2_a2_p005[0]-alpha_obs_f2_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f2_a3[0]:.4f}, with plates: {alpha_obs_f2_a3_p005[0]:.4f}, due to plates: {alpha_obs_f2_a3_p005[0]-alpha_obs_f2_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.2 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.2 Hz):
#  A=0.1 V, no plates: 0.0109, with plates: 0.0263, due to plates: 0.0154
#  A=0.2 V, no plates: 0.0101, with plates: 0.0270, due to plates: 0.0169
#  A=0.3 V, no plates: 0.0091, with plates: 0.0241, due to plates: 0.0150

# %%
k_f3 = estimate_wavenumber(freq=1.3, depth=0.2)

alpha_theo_f3 = spatial_damping_coefficient(k=k_f3, D=0.2, H=0.15)

alpha_obs_f3_a1= get_obs_alpha(amp_f3_a1, x_probe_pos)
alpha_obs_f3_a1_p005 = get_obs_alpha(amp_f3_a1_p005, x_probe_pos)
alpha_obs_f3_a2 = get_obs_alpha(amp_f3_a2, x_probe_pos)
alpha_obs_f3_a2_p005 = get_obs_alpha(amp_f3_a2_p005, x_probe_pos)
alpha_obs_f3_a3 = get_obs_alpha(amp_f3_a3, x_probe_pos)
alpha_obs_f3_a3_p005 = get_obs_alpha(amp_f3_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.3 Hz): ', f'{alpha_theo_f3:.4f}\n')
print('Observed spatial damping coefficients (f=1.3 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f3_a1[0]:.4f}, with plates: {alpha_obs_f3_a1_p005[0]:.4f}, due to plates: {alpha_obs_f3_a1_p005[0]-alpha_obs_f3_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f3_a2[0]:.4f}, with plates: {alpha_obs_f3_a2_p005[0]:.4f}, due to plates: {alpha_obs_f3_a2_p005[0]-alpha_obs_f3_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f3_a3[0]:.4f}, with plates: {alpha_obs_f3_a3_p005[0]:.4f}, due to plates: {alpha_obs_f3_a3_p005[0]-alpha_obs_f3_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.3 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.3 Hz):
#  A=0.1 V, no plates: 0.0106, with plates: 0.0223, due to plates: 0.0117
#  A=0.2 V, no plates: 0.0091, with plates: 0.0218, due to plates: 0.0126
#  A=0.3 V, no plates: 0.0109, with plates: 0.0222, due to plates: 0.0113

# %%
k_f4 = estimate_wavenumber(freq=1.4, depth=0.2)

alpha_theo_f4 = spatial_damping_coefficient(k=k_f4, D=0.2, H=0.15)

alpha_obs_f4_a1= get_obs_alpha(amp_f4_a1, x_probe_pos)
alpha_obs_f4_a1_p005 = get_obs_alpha(amp_f4_a1_p005, x_probe_pos)
alpha_obs_f4_a2 = get_obs_alpha(amp_f4_a2, x_probe_pos)
alpha_obs_f4_a2_p005 = get_obs_alpha(amp_f4_a2_p005, x_probe_pos)
alpha_obs_f4_a3 = get_obs_alpha(amp_f4_a3, x_probe_pos)
alpha_obs_f4_a3_p005 = get_obs_alpha(amp_f4_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.4 Hz): ', f'{alpha_theo_f4:.4f}\n')
print('Observed spatial damping coefficients (f=1.4 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f4_a1[0]:.4f}, with plates: {alpha_obs_f4_a1_p005[0]:.4f}, due to plates: {alpha_obs_f4_a1_p005[0]-alpha_obs_f4_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f4_a2[0]:.4f}, with plates: {alpha_obs_f4_a2_p005[0]:.4f}, due to plates: {alpha_obs_f4_a2_p005[0]-alpha_obs_f4_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f4_a3[0]:.4f}, with plates: {alpha_obs_f4_a3_p005[0]:.4f}, due to plates: {alpha_obs_f4_a3_p005[0]-alpha_obs_f4_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.4 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.4 Hz):
#  A=0.1 V, no plates: 0.0092, with plates: 0.0260, due to plates: 0.0168
#  A=0.2 V, no plates: 0.0095, with plates: 0.0277, due to plates: 0.0182
#  A=0.3 V, no plates: 0.0072, with plates: 0.0232, due to plates: 0.0160

# %%
k_f5 = estimate_wavenumber(freq=1.5, depth=0.2)

alpha_theo_f5 = spatial_damping_coefficient(k=k_f5, D=0.2, H=0.15)

alpha_obs_f5_a1= get_obs_alpha(amp_f5_a1, x_probe_pos)
alpha_obs_f5_a1_p005 = get_obs_alpha(amp_f5_a1_p005, x_probe_pos)
alpha_obs_f5_a2 = get_obs_alpha(amp_f5_a2, x_probe_pos)
alpha_obs_f5_a2_p005 = get_obs_alpha(amp_f5_a2_p005, x_probe_pos)
alpha_obs_f5_a3 = get_obs_alpha(amp_f5_a3, x_probe_pos)
alpha_obs_f5_a3_p005 = get_obs_alpha(amp_f5_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.5 Hz): ', f'{alpha_theo_f5:.4f}\n')
print('Observed spatial damping coefficients (f=1.5 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f5_a1[0]:.4f}, with plates: {alpha_obs_f5_a1_p005[0]:.4f}, due to plates: {alpha_obs_f5_a1_p005[0]-alpha_obs_f5_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f5_a2[0]:.4f}, with plates: {alpha_obs_f5_a2_p005[0]:.4f}, due to plates: {alpha_obs_f5_a2_p005[0]-alpha_obs_f5_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f5_a3[0]:.4f}, with plates: {alpha_obs_f5_a3_p005[0]:.4f}, due to plates: {alpha_obs_f5_a3_p005[0]-alpha_obs_f5_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.5 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.5 Hz):
#  A=0.1 V, no plates: 0.0119, with plates: 0.0213, due to plates: 0.0094
#  A=0.2 V, no plates: 0.0080, with plates: 0.0205, due to plates: 0.0125
#  A=0.3 V, no plates: 0.0090, with plates: 0.0191, due to plates: 0.0101

# %%
k_f6 = estimate_wavenumber(freq=1.6, depth=0.2)

alpha_theo_f6 = spatial_damping_coefficient(k=k_f6, D=0.2, H=0.15)

alpha_obs_f6_a1= get_obs_alpha(amp_f6_a1, x_probe_pos)
alpha_obs_f6_a1_p005 = get_obs_alpha(amp_f6_a1_p005, x_probe_pos)
alpha_obs_f6_a2 = get_obs_alpha(amp_f6_a2, x_probe_pos)
alpha_obs_f6_a2_p005 = get_obs_alpha(amp_f6_a2_p005, x_probe_pos)
alpha_obs_f6_a3 = get_obs_alpha(amp_f6_a3, x_probe_pos)
alpha_obs_f6_a3_p005 = get_obs_alpha(amp_f6_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.6 Hz): ', f'{alpha_theo_f6:.4f}\n')
print('Observed spatial damping coefficients (f=1.6 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f6_a1[0]:.4f}, with plates: {alpha_obs_f6_a1_p005[0]:.4f}, due to plates: {alpha_obs_f6_a1_p005[0]-alpha_obs_f6_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f6_a2[0]:.4f}, with plates: {alpha_obs_f6_a2_p005[0]:.4f}, due to plates: {alpha_obs_f6_a2_p005[0]-alpha_obs_f6_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f6_a3[0]:.4f}, with plates: {alpha_obs_f6_a3_p005[0]:.4f}, due to plates: {alpha_obs_f6_a3_p005[0]-alpha_obs_f6_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.6 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.6 Hz):
#  A=0.1 V, no plates: 0.0119, with plates: 0.0232, due to plates: 0.0113
#  A=0.2 V, no plates: 0.0106, with plates: 0.0251, due to plates: 0.0145
#  A=0.3 V, no plates: 0.0157, with plates: 0.0241, due to plates: 0.0084

# %%
k_f7 = estimate_wavenumber(freq=1.7, depth=0.2)

alpha_theo_f7 = spatial_damping_coefficient(k=k_f7, D=0.2, H=0.15)

alpha_obs_f7_a1= get_obs_alpha(amp_f7_a1, x_probe_pos)
alpha_obs_f7_a1_p005 = get_obs_alpha(amp_f7_a1_p005, x_probe_pos)
alpha_obs_f7_a2 = get_obs_alpha(amp_f7_a2, x_probe_pos)
alpha_obs_f7_a2_p005 = get_obs_alpha(amp_f7_a2_p005, x_probe_pos)
alpha_obs_f7_a3 = get_obs_alpha(amp_f7_a3, x_probe_pos)
alpha_obs_f7_a3_p005 = get_obs_alpha(amp_f7_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.7 Hz): ', f'{alpha_theo_f7:.4f}\n')
print('Observed spatial damping coefficients (f=1.7 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f7_a1[0]:.4f}, with plates: {alpha_obs_f7_a1_p005[0]:.4f}, due to plates: {alpha_obs_f7_a1_p005[0]-alpha_obs_f7_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f7_a2[0]:.4f}, with plates: {alpha_obs_f7_a2_p005[0]:.4f}, due to plates: {alpha_obs_f7_a2_p005[0]-alpha_obs_f7_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f7_a3[0]:.4f}, with plates: {alpha_obs_f7_a3_p005[0]:.4f}, due to plates: {alpha_obs_f7_a3_p005[0]-alpha_obs_f7_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.7 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.7 Hz):
#  A=0.1 V, no plates: 0.0061, with plates: 0.0148, due to plates: 0.0087
#  A=0.2 V, no plates: 0.0057, with plates: 0.0222, due to plates: 0.0165
#  A=0.3 V, no plates: 0.0217, with plates: 0.0183, due to plates: -0.0034

# %%
k_f8 = estimate_wavenumber(freq=1.8, depth=0.2)

alpha_theo_f8 = spatial_damping_coefficient(k=k_f8, D=0.2, H=0.15)

alpha_obs_f8_a1= get_obs_alpha(amp_f8_a1, x_probe_pos)
alpha_obs_f8_a1_p005 = get_obs_alpha(amp_f8_a1_p005, x_probe_pos)
alpha_obs_f8_a2 = get_obs_alpha(amp_f8_a2, x_probe_pos)
alpha_obs_f8_a2_p005 = get_obs_alpha(amp_f8_a2_p005, x_probe_pos)
alpha_obs_f8_a3 = get_obs_alpha(amp_f8_a3, x_probe_pos)
alpha_obs_f8_a3_p005 = get_obs_alpha(amp_f8_a3_p005, x_probe_pos)

print('Theoretical spatial damping coefficient (f=1.8 Hz): ', f'{alpha_theo_f8:.4f}\n')
print('Observed spatial damping coefficients (f=1.8 Hz):')
print(f' A=0.1 V, no plates: {alpha_obs_f8_a1[0]:.4f}, with plates: {alpha_obs_f8_a1_p005[0]:.4f}, due to plates: {alpha_obs_f8_a1_p005[0]-alpha_obs_f8_a1[0]:.4f}')
print(f' A=0.2 V, no plates: {alpha_obs_f8_a2[0]:.4f}, with plates: {alpha_obs_f8_a2_p005[0]:.4f}, due to plates: {alpha_obs_f8_a2_p005[0]-alpha_obs_f8_a2[0]:.4f}')
print(f' A=0.3 V, no plates: {alpha_obs_f8_a3[0]:.4f}, with plates: {alpha_obs_f8_a3_p005[0]:.4f}, due to plates: {alpha_obs_f8_a3_p005[0]-alpha_obs_f8_a3[0]:.4f}')
# Out:
# Theoretical spatial damping coefficient (f=1.8 Hz):  0.0148
#
# Observed spatial damping coefficients (f=1.8 Hz):
#  A=0.1 V, no plates: 0.0121, with plates: 0.0352, due to plates: 0.0231
#  A=0.2 V, no plates: 0.0159, with plates: 0.0330, due to plates: 0.0172
#  A=0.3 V, no plates: 0.0306, with plates: 0.0259, due to plates: -0.0047

# %% [markdown]
# We have from above that, $a_{2} = a_{1}\frac{0.3}{0.2} = a_{1}*1.5$.
#
# Which yields, $a_{2} = 1.5 * a_{1} = 1.5 * (k_{1}*V + b_{1})$. Thus, the voltage setting for the scaled amplitude at 30 cm water depth is,
#
# $V^* = \frac{a_{2} - 1.5*b_{1}}{1.5 * k_{1}}$.
