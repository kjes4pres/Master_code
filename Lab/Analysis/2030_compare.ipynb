# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
from sklearn.metrics import r2_score
from matplotlib.lines import Line2D

sys.path.append('/Users/kjesta/Desktop/LABDATA/Kjersti_100226/')
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Master_code/Lab/')
sys.path.append('/Users/kjesta/Desktop/Master prosjekt/Processed_files/')

from funcs import *
from processing_funcs import *
from analysis_funcs import *

import matplotlib.style as mplstyle
mplstyle.use(["ggplot", "fast"])

import warnings
warnings.filterwarnings("ignore")

# %load_ext autoreload
# %autoreload 2

# %%
data20 = {
    1.1: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a02_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a03_p005_results.csv"),
        },
    },
    1.1: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a02_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f11_a03_p005_results.csv"),
        },
    },
    1.2: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a02_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f12_a03_p005_results.csv"),
        },
    },
    1.3: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a02_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f13_a03_p005_results.csv"),
        },
    },
    1.4: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a02_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f14_a03_p005_results.csv"),
        },
    },
    1.5: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a02_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f15_a03_p005_results.csv"),
        },
    },  
    1.6: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a02_p005_results.csv"),
        },
        0.25: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a025_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a025_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f16_a03_p005_results.csv"),
        },
    },
    1.7: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a02_p005_results.csv"),
        },
        0.25: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a025_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a025_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f17_a03_p005_results.csv"),
        },
    },
    1.8: {
        0.1: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a01_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a01_p005_results.csv"),
        },
        0.2: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a02_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a02_p005_results.csv"),
        },
        0.25: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a025_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a025_p005_results.csv"),
        },
        0.3: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a03_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/20cm_f18_a03_p005_results.csv"),
        },
    },
}

# %%
data30 = {
    0.898: {
        0.149: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0149_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0149_p005_results.csv"),
        },
        0.299: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0299_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0299_p005_results.csv"),
        },
        0.453: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0453_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0898_a0453_p005_results.csv"),
        },
    },
    0.980: {
        0.149: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0149_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0149_p005_results.csv"),
        },
        0.295: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0295_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0295_p005_results.csv"),
        },
        0.443: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0443_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f0980_a0443_p005_results.csv"),
        },
    },
    1.061: {
        0.149: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0149_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0149_p005_results.csv"),
        },
        0.295: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0295_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0295_p005_results.csv"),
        },
        0.449: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0449_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1061_a0449_p005_results.csv"),
        },
    },
    1.143: {
        0.148: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0148_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0148_p005_results.csv"),
        },
        0.295: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0295_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0295_p005_results.csv"),
        },
        0.443: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0443_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1143_a0443_p005_results.csv"),
        },
    },
    1.225: {
        0.152: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0152_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0152_p005_results.csv"),
        },
        0.299: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0299_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0299_p005_results.csv"),
        },
        0.471: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0471_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1225_a0471_p005_results.csv"),
        },
    },
    1.306: {
        0.152: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0152_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0152_p005_results.csv"),
        },
        0.302: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0302_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0302_p005_results.csv"),
        },
        0.372: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0372_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0372_p005_results.csv"),
        },
        0.461: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0461_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1306_a0461_p005_results.csv"),
        },
    },
    1.388: {
        0.147: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0147_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0147_p005_results.csv"),
        },
        0.285: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0285_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0285_p005_results.csv"),
        },
        0.378: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0378_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0378_p005_results.csv"),
        },
        0.468: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0468_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1388_a0468_p005_results.csv"),
        },
    },
    1.470: {
        0.147: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0147_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0147_p005_results.csv"),
        },
        0.296: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0296_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0296_p005_results.csv"),
        },
        0.382: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0382_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0382_p005_results.csv"),
        },
        0.459: {
            None:  pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0459_results.csv"),
            "p005": pd.read_csv("/Users/kjesta/Desktop/LABDATA/Calculated_amps/30cm_f1470_a0459_p005_results.csv"),
        },
    },
}

# %%
freqs20 = list(data20.keys())
volts20 = []

for i in range(len(freqs20)):
    volts20.append(list(data20[freqs20[i]].keys()))

# %%
freqs30 = list(data30.keys())
volts30 = []

for i in range(len(freqs30)):
    volts30.append(list(data30[freqs30[i]].keys()))

# %%
wavenumber20 = []

for f in freqs20:
    wavenumber20.append(estimate_wavenumber(f, 0.2))

# %%
wavenumber30 = []

for f in freqs30:
    wavenumber30.append(estimate_wavenumber(f, 0.3))

# %%
alpha_theo20 = []

# Theoretical spatial damping coefficient for each wavenumber
# With 5 cm tall plates on 30 cm water depth
for k in wavenumber20:
    alpha_theo20.append(spatial_damping_coefficient(k, 0.2, 0.15))

# %%
alpha_theo30 = []

# Theoretical spatial damping coefficient for each wavenumber
# With 5 cm tall plates on 30 cm water depth
for k in wavenumber30:
    alpha_theo30.append(spatial_damping_coefficient(k, 0.3, 0.25))

# %%
rows = []

for f, amps in data30.items():         # outer: frequency
    for a, tags in amps.items():     # middle: amplitude
        for tag, df in tags.items(): # inner: None / "p005"
            for _, row in df.iterrows():
                if a < 0.2:
                    a_tag = 'low'
                if a >= 0.2 and a < 0.305:
                    a_tag = 'medium'
                if a >= 0.370 and a < 0.385:
                    a_tag = 'medium-high'
                if a >= 0.4:
                    a_tag = 'high'
                
                rows.append({
                    "frequency": f,
                    "volt": a,
                    "volt_level": a_tag,
                    "tag": tag,
                    "run": row["Run"],          # R1 / R2 / R3
                    "Amp_obs_P0": row["Amp_obs_P0"],
                    "Amp_obs_P1": row["Amp_obs_P1"],
                    "Amp_obs_P2": row["Amp_obs_P2"],
                    "Amp_obs_P3": row["Amp_obs_P3"],
                    "Alpha_obs": row["Alpha_obs"],
                    "P3_minus_P0": row["P3_minus_P0"],
                    "ak": row["Amp_obs_P0"]*estimate_wavenumber(f, 0.3),
                    "kH": estimate_wavenumber(f, 0.3)*0.3,
                })

df30 = pd.DataFrame(rows)

# %%
rows = []

for f, amps in data20.items():         # outer: frequency
    for a, tags in amps.items():     # middle: amplitude
        for tag, df in tags.items(): # inner: None / "p005"
            for _, row in df.iterrows():
                if a == 0.1:
                    a_tag = 'low'
                if a == 0.2:
                    a_tag = 'medium'
                if a==0.25:
                    a_tag = 'medium-high'
                if a==0.3:
                    a_tag = 'high'
                
                rows.append({
                    "frequency": f,
                    "volt": a,
                    "volt_level": a_tag,
                    "tag": tag,
                    "run": row["Run"],          # R1 / R2 / R3
                    "Amp_obs_P0": row["Amp_obs_P0"],
                    "Amp_obs_P1": row["Amp_obs_P1"],
                    "Amp_obs_P2": row["Amp_obs_P2"],
                    "Amp_obs_P3": row["Amp_obs_P3"],
                    "Alpha_obs": row["Alpha_obs"],
                    "P3_minus_P0": row["P3_minus_P0"],
                    "ak": row["Amp_obs_P0"]*estimate_wavenumber(f, 0.2),
                    "kH": estimate_wavenumber(f, 0.2)*0.2,
                })

df20 = pd.DataFrame(rows)

# %%
no_plates20 = df20[df20["tag"].isna()]
plates20 = df20[df20["tag"] == "p005"]

no_plates30 = df30[df30["tag"].isna()]
plates30 = df30[df30["tag"] == "p005"]

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 6), sharey=True)

ax[0].plot(no_plates20["frequency"], no_plates20["ak"], "o", label="No plates")
ax[0].plot(plates20["frequency"], plates20["ak"], "s", label="With plates")
ax[0].set_xlabel("Frequency (Hz)")
ax[0].set_ylabel("Spatial Damping Coefficient (1/m)")
ax[0].set_title("Spatial Damping Coefficient vs Frequency")
ax[0].legend()

ax[1].plot(no_plates30["frequency"], no_plates30["ak"], "o", label="No plates")
ax[1].plot(plates30["frequency"], plates30["ak"], "s", label="With plates")
ax[1].set_xlabel("Frequency (Hz)")
ax[1].set_ylabel("Spatial Damping Coefficient (1/m)")
ax[1].set_title("Spatial Damping Coefficient vs Frequency")
ax[1].legend()

ax[0].set_xlabel('Frequency (Hz)')
ax[0].set_ylabel('ak')
ax[0].set_title('ak vs frequency for 20 cm water depth')

ax[1].set_xlabel('Frequency (Hz)')
ax[1].set_ylabel('ak')
ax[1].set_title('ak vs frequency for 30 cm water depth')

for a in ax:
    a.minorticks_on()
    a.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
    a.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')

# %%
level_colors = {
    "low":  "C0",
    "medium":  "C1",
    "medium-high": "C2",
    "high": "C3",
}

fig, ax = plt.subplots(1, 2, figsize=(10, 6), sharey=True)

for level, sub in no_plates20.groupby("volt_level"):
    ax[0].scatter(sub["frequency"], sub["Alpha_obs"],
               marker='o',
               label=f'{level} (no plates)',
               color=level_colors.get(level, "gray"))

for level, sub in plates20.groupby("volt_level"):
    ax[0].scatter(sub["frequency"], sub["Alpha_obs"],
               label=f'{level} (5 cm plates)',
               marker='x',
               color=level_colors.get(level, "gray"))
    
for level, sub in no_plates30.groupby("volt_level"):
    ax[1].scatter(sub["frequency"], sub["Alpha_obs"],
               marker='o',
               color=level_colors.get(level, "gray"))

for level, sub in plates30.groupby("volt_level"):
    ax[1].scatter(sub["frequency"], sub["Alpha_obs"],
               marker='x',
               color=level_colors.get(level, "gray"))

for a in ax:
    a.minorticks_on()
    a.grid(which='major', linestyle='-', linewidth='0.5', color='gray')
    a.grid(which='minor', linestyle=':', linewidth='0.5', color='lightgray')
    a.set_xlabel('Frequency (Hz)')
    a.set_ylabel(r'Damping coefficient $\alpha$ (1/m)')

fig.legend(bbox_to_anchor=(0.5, 0.95), title="Voltage Level", ncol=2)

ax[0].set_title('20 cm water depth')
ax[1].set_title('30 cm water depth')
# Out:
# Text(0.5, 1.0, '30 cm water depth')
