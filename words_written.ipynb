# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dates = ['14.01.26', '21.01.26', '27.01.26', '10.02.26', '25.02.26', '26.02.26', '04.03.26', '10.02.26', '12.03.26', '19.03.26', '23.03.26', '24.03.26', '30.03.26', '31.03.26', '02.04.26', '03.04.26', '06.04.26']
dates = pd.to_datetime(dates, format='%d.%m.%y')

# %%
words_written = [6075, 6764, 8098, 8540, 8433, 8405, 9071, 9658, 10240, 11145, 11377, 11712, 12847, 13138, 14297, 15805, 17829]

# %%
plt.figure(figsize=(10, 5))
plt.plot(dates, words_written, marker='o', color='magenta')
plt.xticks(rotation=45)
plt.ylabel('Words Written')
plt.grid()
