# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dates = ['14.01.26', '21.01.26', '27.01.26', '10.02.26', 
         '25.02.26', '26.02.26', '04.03.26', '10.03.26', 
         '12.03.26', '19.03.26', '23.03.26', '24.03.26', 
         '30.03.26', '31.03.26', '02.04.26', '03.04.26', 
         '06.04.26', '07.04.26', '09.04.26', '10.04.26',
         '14.04.26', '15.04.26', '16.04.26', '20.04.26',
         '21.04.26', '22.04.26', '23.04.26', '27.04.26',
         '28.04.26', '29.04.26', '01.05.26', '03.05.26',
         '05.05.26', '06.05.26', '07.05.26', '11.05.26',
         '12.05.26', '13.05.26', '14.05.26', '15.05.26']

dates = pd.to_datetime(dates, format='%d.%m.%y')

# %%
words_written = [6075, 6764, 8098, 8540, 8433, 8405, 9071, 9658, 10240, 11145, 11377, 11712, 12847, 
                 13138, 14297, 15805, 17829, 18856, 19050, 19750, 19579, 19950, 19940, 21947, 22873,
                 23440, 24067, 24030, 24177, 24151, 22944, 23120, 22430, 22331, 22625, 23434, 23754,
                 24098, 24014, 24018]

# %%
plt.figure(figsize=(10, 5))
plt.plot(dates, words_written, marker='o', color='magenta')
plt.xticks(rotation=45)
plt.ylabel('Words Written')
plt.title('Overleaf Word count over time')
plt.grid()
